# %%
from typing import Tuple, Any

import pandas as pd
import numpy as np
import plotly.express as px
import requests
import bs4
from lxml import etree
import re
import fake_useragent
import threading
from queue import Queue
from time import sleep
import random
import configer

# %%
def get_category_data(type: str, cat_name: str = None) -> int | list:

    """
    Returns the requested data by category

    :param type: Type returned data. Should be one of: id, ru_name or cat_names
    :param cat_name: category name
    :return: returns the requested data
    """

    cat = {
        'makijazh':              {'id': 3, 'name': 'макияж'},
        'uhod':                  {'id': 4, 'name': 'уход'},
        'volosy':                {'id': 6, 'name': 'волосы'},
        'parfjumerija':          {'id': 7, 'name': 'парфюмерия'},
        'zdorov-e-i-apteka':     {'id': 3747, 'name': 'здоровье и аптека'},
        'sexual-wellness':       {'id': 5962, 'name': 'sexual wellness'},
        'azija':                 {'id': 10, 'name': 'азия'},
        'organika':              {'id': 12, 'name': 'органика'},
        'dlja-muzhchin':         {'id': 3887, 'name': 'для мужчин'},
        'dlja-detej':            {'id': 4357, 'name': 'для детей'},
        'tehnika':               {'id': 3870, 'name': 'техника'},
        'dlja-doma':             {'id': 8202, 'name': 'для дома'},
        'odezhda-i-aksessuary':  {'id': 8529, 'name': 'одежда и аксессуары'},
        'nizhnee-bel-jo':        {'id': 8563, 'name': 'нижнее бельё'},
        'ukrashenija':           {'id': 5746, 'name': 'украшения'},
        'lajfstajl':             {'id': 8579, 'name': 'лайфстайл'},
        'ini-formaty':           {'id': 5159, 'name': 'тревел-форматы'},
        'tovary-dlja-zhivotnyh': {'id': 7638, 'name': 'товары для животных'}
    }
    
    if type not in ['cat_names', 'id', 'ru_name']:
        raise ValueError('Parameter type should by "cat_names","id" or "ru_name"')
    
    if type == 'cat_names':
        return [cat for cat in cat.keys()]
    
    if cat_name is None:
        raise ValueError('Value cat_name should be not None')
    
    try:
        cat[cat_name]
    except KeyError:
        raise ValueError(f'Wrong category name: {cat_name}. \n'
                         f'Possible cat_names: {", ".join([name for name in cat.keys()])}')

    if type == 'id':
        return cat[cat_name]['id']
    elif type == 'ru_name':
        return cat[cat_name]['name']
    else:
        raise ValueError('type should be "cat_names", "id" or "ru_name"')

# %%
def get_product_data_by_url(url: str) -> tuple[Any, Any, Any]:
    """
    Get additional data by product URL.
    Additional data uncludes:
        - description
        - product usage
        - product composition

    """
    user_agent = fake_useragent.UserAgent().random
    try:
        res = requests.get(url, timeout=5, headers={'User-Agent': user_agent}).text
        res = etree.HTML(res)
    except:
        return None, None, None

    try:
        description: str or None = ' '.join(res.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[1]')[0].text.replace('\n\n', '').split()) \
        if len(res.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[1]')) > 0 \
           and res.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[1]')[0].text is not None\
        else None
    except:
        description = None

    try:
        product_usage: str or None = ' '.join(res.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[2]/article/div/section')[0].text.replace('\n\n', '').split()) \
        if len(res.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[2]/article/div/section')) > 0 \
        else None
    except:
        product_usage = None

    try:
        product_composition: str or None = ' '.join(res.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[3]/article/div/section')[0].text.replace('\n\n', '').split()) \
        if len(res.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[3]/article/div/section')) > 0 \
        else None
    except:
        product_composition = None

    return description, product_usage, product_composition

# %%
def parse_category(queue: Queue, cat_name: str):
    category_id = get_category_data(cat_name=cat_name, type='id')
    category_ru_name = get_category_data(cat_name=cat_name, type='ru_name')
    fields = [
        'id',
        'sku',
        'name',
        'brand',
        'brand_type',
        'dimension17',
        'dimension18',
        'dimension19',
        'dimension20',
        'country',
        'price',
        'currency',
        'old_price',
        'category_type',
        'url',
        'images',
        'type',
        'volume',
        'main_product_sku',
        'main_product_id',
        'best_loyalty_price',
        'dimension29',
        'dimension28',
        'description',
        'product_usage',
        'product_composition',
        'category',
        'category_ru'
        ]

    for page in range(1, 10000):
        try:
            # ждем рандомный момент времени
            sleep(np.round(np.random.uniform(10, 20), 1))
            # генерим рандомный юезерагент
            user_agent = fake_useragent.UserAgent().random
            # пытаемся получить данные по странице с товарами
            res = requests.get(url, params={'cat': category_id, 'page': page}, timeout=5, headers={'User-Agent': user_agent}).json()['products']
        except:
            break
        # в случае количества страниц, кратным 20 можем получить страницу с 0 товарами
        if len(res) == 0:
            break
        # если добрались до последней страницы, собираем с нее остатки и возвращаем результат
        elif len(res) < 20:
            for product in res:
                # фильтруем только необходимые поля, если поля нет, то None
                product_new = {your_key: product[your_key] if your_key in product.keys() else None  for your_key in fields}
                # получаем данные из html странички, которые отсутствуют в запросе (исключив это можно значительно сократить время парсинга)
                description, product_usage, product_composition = get_product_data_by_url(product['url'])
                product_new['description'] = description
                product_new['product_usage'] = product_usage
                product_new['product_composition'] = product_composition
                product_new['category'] = cat_name
                product_new['category_ru'] = category_ru_name
                # кладем объект в очередь
                queue.put(product_new)
                queue.task_done()
            break
        else:
            for product in res:
                # фильтруем только необходимые поля, если поля нет, то None
                product_new = {your_key: product[your_key] if your_key in product.keys() else None  for your_key in fields}
                # получаем данные из html странички, которые отсутствуют в запросе (исключив это можно значительно сократить время парсинга)
                description, product_usage, product_composition = get_product_data_by_url(product['url'])
                product_new['description'] = description
                product_new['product_usage'] = product_usage
                product_new['product_composition'] = product_composition
                product_new['category'] = cat_name
                product_new['category_ru'] = category_ru_name
                # кладем объект в очередь
                queue.put(product_new)
                queue.task_done()

# %%
def save_to_pd_dataframe(queue: Queue, df: pd.DataFrame):
    while True:
        try:
            # sleep + timeout в requests не должны превышать данный timeout иначе парсинг может закончится раньше времени
            product_data = queue.get(timeout=30)
            df = pd.concat([
                df,
                pd.DataFrame([product_data])
            ])
            print(f'Len data: {len(df)}', end='\r')
        except:
            # если за 30 секунд в очереди не появилось данных, полагаем что парсинг завершен
            df.to_csv('products.csv', index=False)
            break

# %%
agent = fake_useragent.UserAgent().random
queue = Queue()
df = pd.DataFrame()
url = 'https://goldapple.ru/web_scripts/discover/category/products/'

# %%
categories_name = get_category_data(type='cat_names')

# создаем поток для каждой категории
threads = [threading.Thread(target=parse_category, args=(queue, category_name)) for category_name in categories_name]
# создаем поток для сохранения результатов парсинга в df
threads.append(threading.Thread(target=save_to_pd_dataframe, args=(queue, df)))
# стартуем потоки
[t.start() for t in threads]
# ждем завершения парсинга и сохранения результатов
[t.join() for t in threads]
# Out:
# Len data: 40580
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
data = pd.read_csv('products.csv')
data.info()

# %%
data.head(40)

# %%
data['brand_type'].value_counts()

# %%
res

# %%
res = requests.get('https://goldapple.ru/19000032959-detangling-comb-detangling-dog-grooming-brush-navy-orange').text
res = etree.HTML(res)
res.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[1]')[0].text is not None

# %%
def get_sitemats_list(url: str='https://goldapple.ru/sitemap.xml') -> list[str]:
    """
    Get sitemaps list from goldapple or another url.
    :param url: url to sitemap.xml
    :return: list of sitemaps urls
    """
    try:
        res = requests.get(url, timeout=30).text
    except requests.exceptions.ConnectTimeout as err:
        raise requests.exceptions.ConnectTimeout(f'connection timeout, {err}')
    except requests.exceptions.ConnectionError:
        raise requests.exceptions.ConnectionError(f'check url: {url}')
    except requests.exceptions.HTTPError as err:
        raise requests.exceptions.HTTPError(err)

    try:
        soup = bs4.BeautifulSoup(res, 'xml')
        res = [x.text for x in soup.find_all('loc')]
    except AttributeError as err:
        raise AttributeError(f'could not find attribute "loc", {err}')
    except Exception as err:
        raise f'Error parsing xml data: {err}'

    return res

# %%
def get_product_urls(sitemaps: list[str]) -> list[str]:
    """
    Get products urls from sitemaps.

    :param sitemaps: list of sitemaps urls
    :return: list of product links
    """
    cat_urls = []
    prod_urls = []
    pattern = re.compile(r'\d{10,12}')
    for sitemap in sitemaps:
        xml_products = requests.get(sitemap).text
        soup_products = bs4.BeautifulSoup(xml_products, 'xml')
        product_urls = [x.text for x in soup_products.find_all('loc')]
        for index, x in enumerate(product_urls):
            product = re.findall(pattern, x)
            if product:
                prod_urls.append(product_urls[index])
            else:
                cat_urls.append(product_urls[index])
    return cat_urls, prod_urls

# %%
def get_sku_and_product_id(url: str) -> tuple[Any, Any]:
    """
    Return sku_id and product_id from product URL
    :param url: url to product
    :return: [sku_id, prod_id]
    """
    pattern = re.compile(r'\d{4,20}')
    res_sku = re.findall(pattern, url)
    if len(res_sku) == 1:
        prod_id = None
        sku_id = res_sku[0]
    elif len(res_sku) > 1:
        prod_id = res_sku[0]
        sku_id = res_sku[1]
    else:
        prod_id = sku_id = None

    return sku_id, prod_id

# %%
sitemaps = get_sitemats_list()
cat_urls, product_urls = get_product_urls(sitemaps)

# %%
requests.get('https://goldapple.ru/web_scripts/discover/category/products/', params={'cat': 3}, ).json()['products']

# %%
old = {'id': '173372',
  'sku': '19000016941',
  'name': 'К122',
  'brand': 'Manly PRO',
  'brand_type': 'standard',
  'dimension17': 'Кисти для лица',
  'dimension18': 'Женский',
  'dimension19': None,
  'dimension20': None,
  'country': 'Россия',
  'price': 1630,
  'price_object': {'amount': '1630', 'currency': 'RUB'},
  'old_price': 1630,
  'old_price_object': {'amount': '1630', 'currency': 'RUB'},
       'category_type': 'Большая плоская кисть для пудры ',
  'url': 'https://goldapple.ru/19000016941-k122',
  'image_url': 'https://goldapple.ru/media/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg',
  'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
  'images': ['https://goldapple.ru/media/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg',
   'https://goldapple.ru/media/catalog/product/6/9/6921166812419_2_chfmwll08kkefjw8.jpg',
   'https://goldapple.ru/media/catalog/product/6/9/6921166812419_3_3apxe5hspdnd5it6.jpg'],
  'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
   'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_2_chfmwll08kkefjw8.jpg?quality=83',
   'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_3_3apxe5hspdnd5it6.jpg?quality=83'],
  'is_saleable': True,
  'type': 'simple',
  'volume': '1',
       'best_loyalty_price': 1467,
  'best_loyalty_price_object': {'amount': '1467', 'currency': 'RUB'},
  'dimension29': False,
  'dimension28': False,
  'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=0&p=19000016941&rid=msk&mvtId=55814&mvtTs=1656858237280',
       'resized_gallery_images': [],
  'need_render_old_price': True,
  'main_product_sku': '19000016941',
  'main_product_id': '173372',}

fields = [
        'id',
        'sku',
        'name',
        'brand',
        'brand_type',
        'dimension17',
        'dimension18',
        'dimension19',
        'dimension20',
        'country',
        'price',
        'old_price',
        'category_type',
        'url',
        'images',
        'type',
        'volume',
        'main_product_sku',
        'main_product_id',
        'best_loyality_price',
        'dimension29',
        'dimension28',
        'description',
        'product_usage',
        'product_composition',
        'category',
        'category_ru'
        ]

dict_you_want = {your_key: old[your_key] if your_key in old.keys() else None  for your_key in fields }
dict_you_want

# %%
product_template = {
    'id': None,
    'sku': None,
    'name': None,
    'brand': None,
    'brand_type': None,
    'dimension17': None,
    'dimension18': None,
    'dimension19': None,
    'dimension20': None,
    'country': None,
    'price': None,
    'currency': None,
    'old_price': None,
    'category_type': None,
    'url': None,
    'images': None,
    'type': None,
    'volume': None,
    'main_product_sku': None,
    'main_product_id': None,
    'best_loyality_price': None,
    'dimension29': None,
    'dimension28': None,
    'description': None,
    'product_usage': None,
    'product_composition': None,
    'category': None,
    'category_ru': None
}

# %%
len(cat_urls)

# %%
counter = 0
for url in cat_urls:
    url = url.split('https://goldapple.ru/')[1].split('/')
    print(url)
    counter += 1
    # if counter > 20:
    #     break

# %%
class Product:
    def __init__(self, product_page, product_url:str=None, product_id:int=None, sku_id:int=None):
        self.product_page: etree._Element = etree.HTML(product_page)
        self.product_url = product_url
        self.product_id: int or None = product_id
        self.sku_id: int or None = sku_id
        self.title: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/header/p')[0].text.strip() \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/header/p')) > 0 \
            else None
        self.first_subcategory: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[2]/a/span')[0].text.strip() \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[2]/a/span')) > 0 \
            else None
        self.second_subcategory: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[3]/a/span')[0].text.strip() \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[3]/a/span')) > 0 \
            else None
        self.third_subcategory: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[4]/a/span')[0].text.strip() \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[4]/a/span')) > 0 \
            else None
        self.fourth_subcategory: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[5]/a/span')[0].text.strip() \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[5]/a/span')) > 0 \
            else None
        self.price: int or None = int(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/form/div[3]/div/div/span/span/span/span')[0].text.replace('₽', '').replace(u'\xa0', u' ').replace(u' ', u'').strip()) \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/form/div[3]/div/div/span/span/span/span')) > 0 \
            else None
        self.loyalty_price: int or None = int(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/form/div[3]/div/span/span/span/span')[0].text.replace('₽', '').replace(u'\xa0', u' ').replace(u' ', u'').strip()) \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/form/div[3]/div/span/span/span/span')) > 0 \
            else None
        self.description: str or None = ' '.join(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[1]')[0].text.replace('\n\n', '').split()) \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[1]')) > 0 \
            else None
        self.product_usage: str or None = ' '.join(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[2]/article/div/section')[0].text.replace('\n\n', '').split()) \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[2]/article/div/section')) > 0 \
            else None
        self.product_composition: str or None = ' '.join(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[3]/article/div/section')[0].text.replace('\n\n', '').split()) \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[3]/article/div/section')) > 0 \
            else None
        self.product_brand: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[3]/article/div/header/h4/span')[0].text \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[3]/article/div/header/h4/span')) > 0 \
            else None or self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[2]/article/div/header/h4/span')[0].text \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[2]/article/div/header/h4/span')) > 0 \
            else None

# %%
len(product_urls)

# %%
url = product_urls[4000]
res = requests.get(url, timeout=(3, 5)).content.decode('utf-8')

# %%
url

# %%
res = requests.get('https://goldapple.ru/web_scripts/discover/category/products/', params={'cat': 3, 'page': 1}).json()['products']
len(res)
res[0]

# %%
res = requests.get('https://goldapple.ru/web_scripts/discover/category/products/', params={'cat': 3, 'page': 743}).json()['products']
len(res)

# %%
from selenium import webdriver

browser = webdriver.Edge(executable_path='msedgedriver.exe')
browser.get(url)
html = browser.page_source
tree = etree.HTML(html)
tree.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[2]/a/span')

# %%
res

# %%
res_soup = bs4.BeautifulSoup(res, 'html.parser')
tree = etree.HTML(res)

# %%
res_soup.find('div', {'class': 'product-card'})

# %%
tree.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[2]/a/span')

# %%
prod = Product(res)

# %%
prod.__dict__

# %%
for x in res_soup.find_all('li', {'class': "pdp-breadcrumbs__crumb-item pdp-breadcrumbs__item"}):
    print(x.get_text())

# %%
str(etree.tostring(tree.xpath('/html/body')[0])).find('')

# %%
product_properties = {}
for x in tree.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[2]/dl')[0]:
    print(x[0][0].text)
    if 'Тип продукта' in x[0][0].text:
        product_properties['product_type'] = x[1][0].text
    if 'Для кого' in x[0][0].text:
        product_properties['who_use'] = x[1][0].text
    if 'Страна бренда' in x[0][0].text:
        product_properties['brand_country'] = x[1][0].text
    if 'Область применения' in x[0][0].text:
        product_properties['use_scope'] = x[1][0].text
    if 'Назначение' in x[0][0].text:
        product_properties['purpose'] = x[1][0].text

product_properties

# %%
MyClass = type("MyClass", (object, ), product_properties)

# %%
link = 'https://goldapple.ru/14503-4551247598-rastusevka-bez-granicdsf'
pattern = re.compile(r'\d{4,20}')
res_sku = re.findall(pattern, link)
if len(res_sku) == 1:
    prod_id = None
    sku_id = res_sku[0]
elif len(res_sku) > 1:
    prod_id = res_sku[0]
    sku_id = res_sku[1]
else:
    prod_id = sku_id = None
print(res_sku)
print(prod_id, sku_id)

# %%
data.head(40)
# Out:
#         id                sku                                  name  \
# 0   201225        19000049706                           темно-синий
# 1   214715        19000067648               Prestige Santorini Blue
# 2   173622        19000019748                 STEAMPOD 3.0 x BARBIE
# 3   224665        19000077743                        Blue Valentine
# 4   222155        19000070441                       Female Multiple
# 5   155448        19760318176                        TIME CONTROL +
# 6   169605  12241-19000013502                       лазурно-голубой
# 7   148215        22470300026          из серебра с алмазной гранью
# 8   148216        22470300027          из серебра с алмазной гранью
# 9   200485        19000046442                         Catnip Chaser
# 10  149704        19760314075                           с фианитами
# 11  222831        19000075163                             Гибкий ум
# 12  200224        19000046406        New Comfort XS Cord 3 m, black
# 13  151709        19760331641                                анклет
# 14  187684        19000034334       Go Isotonic Energy Gels orange
# 15  221038        19000076008  keratin and Pro-Vitamin B5 for dogs
# 16  151711        19760331652                       Утонченная Мари
# 17  148897        19760309096             Platinum Men Beard Maniac
# 18  226042        19000027539                          HYDRATE MASK
# 19  187777        19000034682                          Frozen Might
# 20  171634        19000003077                 Cool kids body lotion
# 21  198266        19000049904                           DOGGY STYLE
# 22   35012        15081300020         Optimale Deodorant 24 Heures
# 23  218782        19000067073                          Wine Culture
# 24  153461        19760318173                  SKINTELLIGENCE HYDRA
# 25  122683        15481300111               Revitalising Scalp Mask
# 26  200497        19000046477        Diamond double cats dish, Lime
# 27   58422         1493200029                      Fusion5 ProGlide
# 28  222290        19000068068           Compartmental dish on stand
# 29  200605        19000046684                     Jive Small 6,6 cm
# 30  165288        19000010992                            SKY SOLID
# 31  211464        19000044459                            WHITEWATER
# 32  154192        19760309112             Algorithm Radical Renewal
# 33  202556        19000025382            SALT FACIAL SCRUB ORIGINAL
# 34  193214        19000022524                              объемный
# 35  230198        19000082151              NOURISHING SOLID SHAMPOO
# 36  108583   10020-1053500001                        Энергия и сила
# 37  160025        19000001291     [C] Anti-Ox Radiance Concentrate
# 38  161955        19000007001                      Studded Lemonade
# 39  144084        19760306242     Magic Glow GLOW REVITALIZING MASK
#
#                        brand brand_type           dimension17 dimension18  \
# 0                      Tkano   standard      Постельное белье     Унисекс
# 1                      ILUXE   standard                   н/д     Унисекс
# 2      L'Oreal Professionnel   standard               Стайлер     Унисекс
# 3                    MORФEUS   standard      Постельное белье     Унисекс
# 4                     Solgar   standard                   н/д     Женский
# 5                     TALIKA   standard              Массажер     Женский
# 6                  Belle YOU   standard            Комбинезон     Женский
# 7                    SOKOLOV   standard                Серьги     Женский
# 8                    SOKOLOV   standard                Серьги     Женский
# 9                  Petstages   standard  игрушка для животных         NaN
# 10                   SOKOLOV   standard               Браслет     Женский
# 11                       МИФ   standard                   NaN     Унисекс
# 12                     Flexi   standard               поводок         NaN
# 13          Nothing but Love   standard               Браслет     Женский
# 14          Science in Sport   standard                   NaN     Унисекс
# 15                Doctor VIC   standard              бальзам          NaN
# 16          Nothing but Love   standard               Браслет     Женский
# 17             DR IRENA ERIS   standard                 Масло     Мужской
# 18  Authentic Beauty Concept   standard                 Маска     Женский
# 19                    Umight   standard                   NaN     Унисекс
# 20               roofa spain   standard                Лосьон   Для детей
# 21                Hair Sekta   standard  шампунь для животных         NaN
# 22                     PAYOT   standard            Дезодорант     Мужской
# 23         LSA International   standard                Бокалы     Унисекс
# 24                    TALIKA   standard    Пенка для умывания     Женский
# 25                Omorovicza   standard                 Маска     Женский
# 26               SuperDesign   standard                 миска         NaN
# 27                  Gillette   standard               Кассеты     Мужской
# 28                Welovewood   standard             Менажница     Унисекс
# 29                  Zogoflex   standard  игрушка для животных         NaN
# 30                   Cirkle    standard               Шампунь     Унисекс
# 31                 Old Spice   standard         Гель для душа     Мужской
# 32             DR IRENA ERIS   standard                  Крем     Унисекс
# 33                   Kosette   standard                 Скраб     Унисекс
# 34          Nothing but Love   standard               Браслет     Женский
# 35                   Clarins   standard               Шампунь     Женский
# 36                     NIVEA   standard               Шампунь     Мужской
# 37                       SVR   standard             Сыворотки     Унисекс
# 38                    Sagami   standard          Презервативы     Унисекс
# 39                  DARLING*   standard        Маски тканевые     Унисекс
#
#                   dimension19       dimension20         country  ...  \
# 0                         NaN               NaN          Россия  ...
# 1                         NaN               NaN          Россия  ...
# 2                         NaN               NaN         Франция  ...
# 3                         NaN               NaN          Россия  ...
# 4            Женское здоровье               NaN             США  ...
# 5                         NaN               NaN         Франция  ...
# 6                         NaN               NaN          Россия  ...
# 7                         NaN               NaN             NaN  ...
# 8                         NaN               NaN             NaN  ...
# 9                         NaN               NaN             США  ...
# 10                        NaN               NaN             NaN  ...
# 11                        NaN               NaN             NaN  ...
# 12                        NaN               NaN        Германия  ...
# 13                        NaN               NaN             NaN  ...
# 14         Спортивное питание               NaN             NaN  ...
# 15                        NaN               NaN        Беларусь  ...
# 16                        NaN               NaN             NaN  ...
# 17       Увлажнение и питание              Лицо          Польша  ...
# 18                        NaN               NaN             NaN  ...
# 19                        NaN               NaN          Россия  ...
# 20                        NaN              Тело             NaN  ...
# 21                        NaN               NaN          Россия  ...
# 22                        NaN              Тело         Франция  ...
# 23                        NaN               NaN  Великобритания  ...
# 24                   Очищение              Лицо         Франция  ...
# 25                        NaN               NaN         Венгрия  ...
# 26                        NaN               NaN           Китай  ...
# 27                 Для бритья              Тело             США  ...
# 28                        NaN               NaN          Россия  ...
# 29                        NaN               NaN             США  ...
# 30                        NaN               NaN         Испания  ...
# 31                        NaN  Для душа и ванны             США  ...
# 32  Против признаков старения              Лицо          Польша  ...
# 33                   Очищение              Лицо             NaN  ...
# 34                        NaN               NaN             NaN  ...
# 35                        NaN               NaN         Франция  ...
# 36                        NaN               NaN             NaN  ...
# 37  Против признаков старения              Лицо         Франция  ...
# 38                        NaN               NaN          Япония  ...
# 39       Увлажнение и питание              Лицо             NaN  ...
#
#     main_product_sku  main_product_id  best_loyality_price dimension29  \
# 0        19000049706           201225                  NaN       False
# 1        19000067648           214715                  NaN       False
# 2        19000019748           173622                  NaN       False
# 3        19000077743           224665                  NaN       False
# 4        19000070441           222155                  NaN       False
# 5        19760318176           155448                  NaN       False
# 6        19000013502           169604                  NaN       False
# 7        22470300026           148215                  NaN       False
# 8        22470300027           148216                  NaN       False
# 9        19000046442           200485                  NaN       False
# 10       19760314075           149704                  NaN       False
# 11       19000075163           222831                  NaN       False
# 12       19000046406           200224                  NaN       False
# 13       19760331641           151709                  NaN       False
# 14       19000034334           187684                  NaN       False
# 15       19000076008           221038                  NaN       False
# 16       19760331652           151711                  NaN       False
# 17       19760309096           148897                  NaN       False
# 18       19000027539           226042                  NaN       False
# 19       19000034682           187777                  NaN       False
# 20       19000003077           171634                  NaN       False
# 21       19000049904           198266                  NaN       False
# 22       15081300020            35012                  NaN       False
# 23       19000067073           218782                  NaN       False
# 24       19760318173           153461                  NaN       False
# 25       15481300111           122683                  NaN       False
# 26       19000046477           200497                  NaN       False
# 27        1493200029            58422                  NaN       False
# 28       19000068068           222290                  NaN       False
# 29       19000046684           200605                  NaN       False
# 30       19000010992           165288                  NaN        True
# 31       19000044459           211464                  NaN       False
# 32       19760309112           154192                  NaN       False
# 33       19000025382           202556                  NaN       False
# 34       19000022524           193214                  NaN       False
# 35       19000082151           230198                  NaN       False
# 36        1050100024            54501                  NaN       False
# 37       19000001291           160025                  NaN       False
# 38       19000007001           161955                  NaN       False
# 39       19760306242           144084                  NaN       False
#
#    dimension28                                        description  \
# 0        False  Комплект постельного белья темно-синего цвета ...
# 1        False  Набор сомелье iLUXE Prestige разработан специа...
# 2        False  Лимитированный профессиональный паровой стайле...
# 3        False  Евро-комплект постельного белья Blue Valentine...
# 4        False  Данный комплекс создан специально для женщин и...
# 5         True                               Косметический прибор
# 6        False  Базовый комбинезон с шортами выполнен из мягко...
# 7        False                                                NaN
# 8        False                                                NaN
# 9        False  Игрушка трек с пластиковым мячиком, тубом коша...
# 10       False                                                NaN
# 11       False  Эта книга призвана развенчать мифы о человечес...
# 12       False  Благодаря яркому двухцветному дизайну этот пов...
# 13       False                                                NaN
# 14       False  Изотонический углеводный гель SiS Go Isotonic ...
# 15        True  Экспертная забота о красоте и здоровье вашего ...
# 16       False                                                NaN
# 17        True  Масло Dr Irena Eris питает и смягчает бороду, ...
# 18       False                                     ЧИСТЫЕ ФОРМУЛЫ
# 19       False  Frozen Might – это смесь для приготовления про...
# 20        True                                    Лосьон для тела
# 21       False  Особенности: Безопасный состав. Эффективное оч...
# 22        True  Дезодорант-ролик Payot Optimale Deodorant 24 H...
# 23       False  В набор входят 2 бокала-флейты из выдувного ст...
# 24        True                              Нежная пенка для лица
# 25        True  Восстанавливающая детокс-маска для кожи головы...
# 26       False  Двойная миска на меламиновой подставке для под...
# 27       False                 Сменные кассеты для мужской бритвы
# 28        True  Деревянная менажница с ручками на 5 секций из ...
# 29       False  Игрушка предназначена специально для собак с в...
# 30       False  Новый формат ухода за вашими волосами! Твердый...
# 31       False  Многие считают, что вода — самый мощный элемен...
# 32       False  Дневной крем Dr Irena Eris, основанный на рево...
# 33        True                                       Нежный скраб
# 34       False                                                NaN
# 35        True  Твердый шампунь - это удобный и экологичный сп...
# 36       False  Когда торопишься, некогда разбираться с флакон...
# 37       False  Восстанавливающий концентрат для сияния кожи и...
# 38       False  Латексные презервативы с обильной точечной тек...
# 39        True  Чтобы потом посмотреть в зеркало и сказать "та...
#
#                                         product_usage  \
# 0                            100% органический хлопок
# 1   1. Установите резак поверх горлышка горизонтал...
# 2   Предварительно нанесите на влажные волосы крем...
# 3   Перед первым использованием рекомендуем постир...
# 4   Женщинам по 1 таблетке 3 раза в день во время ...
# 5   включите прибор, нажав кнопку, и подождите, по...
# 6                   нательное, для домаших тренировок
# 7                                                 NaN
# 8                                                 NaN
# 9   Подбирайте игрушки в соответствии с весом и дв...
# 10                                                NaN
# 11                                      картон/бумага
# 12  Flexi позволит вам вам и вашему питомцу оптима...
# 13                                                NaN
# 14  Один гель каждые 30-40 минут, максимум 3 геля ...
# 15  1.Бальзам-маску можно использовать с водой люб...
# 16                                                NaN
# 17  разотрите несколько капель масла в ладонях, за...
# 18  Нанесите на чистые влажные волосы по длине и н...
# 19  1.1 Для приготовления 3-х порций мороженого не...
# 20  нанесите после купания на чистую и сухую кожу ...
# 21  Нанести необходимое количество шампуня на влаж...
# 22  Перед нанесением дезодоранта, очистите кожу с ...
# 23                                    выдувное стекло
# 24  вспеньте средство в ладонях. Нанесите пенку на...
# 25  Нанесите по проборам на сухую кожу головы, исп...
# 26  Наполните миску необходимым количеством воды и...
# 27  Более ста лет компания меняет бритье к лучшему...
# 28                               Для сервировки стола
# 29  Игрушка при отскакивании от поверхности делает...
# 30  Нанесите шампунь на влажные волосы, проведя им...
# 31  Aqua, Sodium Laureth Sulfate, Sodium Chloride,...
# 32  наносите днём на сухую и чистую кожу. Подходит...
# 33  Нанесите на чистую и влажную кожу, затем аккур...
# 34                                                NaN
# 35  Вспеньте шампунь непосредственно на влажной ко...
# 36  Нанесите на влажные волосы массирующими движен...
# 37  Наносить утром и/или вечером самостоятельно ил...
# 38                                 натуральный латекс
# 39  Достать маску из упаковки, снять с нее защитны...
#
#                                   product_composition               category  \
# 0                                                 NaN              dlja-doma
# 1              Материал корпуса – алюминий и пластик.              dlja-doma
# 2   Марка L’Oréal Professionnel стала известной в ...                tehnika
# 3                                 100% хлопок, сатин.              dlja-doma
# 4                                      Кальций 133 мг      zdorov-e-i-apteka
# 5   АБС-терполимер Термопластический эластомер USB...                tehnika
# 6                            96% полиамид, 4% эластан         nizhnee-bel-jo
# 7                                                 NaN            ukrashenija
# 8                                                 NaN            ukrashenija
# 9                                             Пластик  tovary-dlja-zhivotnyh
# 10                                                NaN            ukrashenija
# 11  Мы издаем книги больше 17 лет. За эти годы вып...              lajfstajl
# 12                               Ударопрочный пластик  tovary-dlja-zhivotnyh
# 13                                                NaN            ukrashenija
# 14  Энергетическая ценность 370 кДж/87 ккал, Жиры ...              lajfstajl
# 15  Аqua, cetearyl alcohol, behenamidopropyl dimet...  tovary-dlja-zhivotnyh
# 16                                                NaN            ukrashenija
# 17  Prunus Amygdalus Dulcis (Sweet Almond) Oil, Is...          dlja-muzhchin
# 18  Aqua (Water, Eau) Cetearyl Alcohol C9-12 Alkan...                 volosy
# 19  Концентрат сывороточных белков, натуральный по...              lajfstajl
# 20  Aqua (Thermal Water), Caprylyc/Capric Triglyce...             dlja-detej
# 21  Aqua, Sodium Coco-Sulfate, Decyl Glucoside, Co...  tovary-dlja-zhivotnyh
# 22  AQUA (WATER) • ALUMINUM CHLOROHYDRATE • STEARE...          dlja-muzhchin
# 23                                                NaN              dlja-doma
# 24  Aqua (Water / Eau), Glycerin, Coco-Glucoside, ...                   uhod
# 25  Aqua (Hungarian Thermal Water), Cetearyl Alcoh...                 volosy
# 26                 60% Меламин, 40% нержавеющая сталь  tovary-dlja-zhivotnyh
# 27                                                NaN          dlja-muzhchin
# 28  Массив ясеня, масло для рабочих поверхностей, ...              dlja-doma
# 29                     Пластик не содержащий фталатов  tovary-dlja-zhivotnyh
# 30  SODIUM LAUROYL METHYL ISETHIONATE, AQUA, PARFU...                 volosy
# 31                                                NaN          dlja-muzhchin
# 32  Aqua (Water), Isopropyl Isostearate, Ethylhexy...                   uhod
# 33  Glycerin, Sea Salt, Water, Silica, Coco-glucos...                  azija
# 34                                                NaN   odezhda-i-aksessuary
# 35  DISODIUM LAURYL SULFOSUCCINATE, SODIUM COCOYL ...                 volosy
# 36  Aqua, Sodium Laureth Sulfate, Cocamidopropyl B...          dlja-muzhchin
# 37  AQUA/WATER/EAU, 3-O-ETHYL ASCORBIC ACID, PROPY...                   uhod
# 38                                                NaN        sexual-wellness
# 39  Water, Saccharomyces Ferment Filtrate, Butylen...                  azija
#
#             category_ru
# 0              для дома
# 1              для дома
# 2               техника
# 3              для дома
# 4     здоровье и аптека
# 5               техника
# 6          нижнее бельё
# 7             украшения
# 8             украшения
# 9   товары для животных
# 10            украшения
# 11            лайфстайл
# 12  товары для животных
# 13            украшения
# 14            лайфстайл
# 15  товары для животных
# 16            украшения
# 17           для мужчин
# 18               волосы
# 19            лайфстайл
# 20            для детей
# 21  товары для животных
# 22           для мужчин
# 23             для дома
# 24                 уход
# 25               волосы
# 26  товары для животных
# 27           для мужчин
# 28             для дома
# 29  товары для животных
# 30               волосы
# 31           для мужчин
# 32                 уход
# 33                 азия
# 34  одежда и аксессуары
# 35               волосы
# 36           для мужчин
# 37                 уход
# 38      sexual wellness
# 39                 азия
#
# [40 rows x 28 columns]

# %%
data['brand_type'].value_counts()
# Out:
# standard    1094
# middle        23
# special        3
# Name: brand_type, dtype: int64

# %%
res
# Out:
# <coroutine object parse_category at 0x000001E81DE645F0>

# %%
res = requests.get('https://goldapple.ru/19000032959-detangling-comb-detangling-dog-grooming-brush-navy-orange').text
res = etree.HTML(res)
res.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[1]')[0].text is not None
# Out:
# False

# %%
def get_sitemats_list(url: str='https://goldapple.ru/sitemap.xml') -> list[str]:
    """
    Get sitemaps list from goldapple or another url.
    :param url: url to sitemap.xml
    :return: list of sitemaps urls
    """
    try:
        res = requests.get(url, timeout=30).text
    except requests.exceptions.ConnectTimeout as err:
        raise requests.exceptions.ConnectTimeout(f'connection timeout, {err}')
    except requests.exceptions.ConnectionError:
        raise requests.exceptions.ConnectionError(f'check url: {url}')
    except requests.exceptions.HTTPError as err:
        raise requests.exceptions.HTTPError(err)

    try:
        soup = bs4.BeautifulSoup(res, 'xml')
        res = [x.text for x in soup.find_all('loc')]
    except AttributeError as err:
        raise AttributeError(f'could not find attribute "loc", {err}')
    except Exception as err:
        raise f'Error parsing xml data: {err}'

    return res

# %%
def get_product_urls(sitemaps: list[str]) -> list[str]:
    """
    Get products urls from sitemaps.

    :param sitemaps: list of sitemaps urls
    :return: list of product links
    """
    cat_urls = []
    prod_urls = []
    pattern = re.compile(r'\d{10,12}')
    for sitemap in sitemaps:
        xml_products = requests.get(sitemap).text
        soup_products = bs4.BeautifulSoup(xml_products, 'xml')
        product_urls = [x.text for x in soup_products.find_all('loc')]
        for index, x in enumerate(product_urls):
            product = re.findall(pattern, x)
            if product:
                prod_urls.append(product_urls[index])
            else:
                cat_urls.append(product_urls[index])
    return cat_urls, prod_urls

# %%
def get_sku_and_product_id(url: str) -> tuple[Any, Any]:
    """
    Return sku_id and product_id from product URL
    :param url: url to product
    :return: [sku_id, prod_id]
    """
    pattern = re.compile(r'\d{4,20}')
    res_sku = re.findall(pattern, url)
    if len(res_sku) == 1:
        prod_id = None
        sku_id = res_sku[0]
    elif len(res_sku) > 1:
        prod_id = res_sku[0]
        sku_id = res_sku[1]
    else:
        prod_id = sku_id = None

    return sku_id, prod_id

# %%
sitemaps = get_sitemats_list()
cat_urls, product_urls = get_product_urls(sitemaps)

# %%
requests.get('https://goldapple.ru/web_scripts/discover/category/products/', params={'cat': 3}, ).json()['products']
# Out:
# [{'id': '173372',
#   'sku': '19000016941',
#   'name': 'К122',
#   'brand': 'Manly PRO',
#   'brand_type': 'standard',
#   'dimension17': 'Кисти для лица',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'Россия',
#   'price': 1630,
#   'price_object': {'amount': '1630', 'currency': 'RUB'},
#   'old_price': 1630,
#   'old_price_object': {'amount': '1630', 'currency': 'RUB'},
#   'category_type': 'Большая плоская кисть для пудры ',
#   'url': 'https://goldapple.ru/19000016941-k122',
#   'image_url': 'https://goldapple.ru/media/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg',
#    'https://goldapple.ru/media/catalog/product/6/9/6921166812419_2_chfmwll08kkefjw8.jpg',
#    'https://goldapple.ru/media/catalog/product/6/9/6921166812419_3_3apxe5hspdnd5it6.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_2_chfmwll08kkefjw8.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_3_3apxe5hspdnd5it6.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'simple',
#   'volume': '1',
#   'tone_swatch': '',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/6/9/6921166812419_1_mixjzksioyjod7da.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/6/9/6921166812419_1_mixjzksioyjod7da.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/6/9/6921166812419_1_mixjzksioyjod7da.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/6/9/6921166812419_1_mixjzksioyjod7da.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '19000016941',
#   'main_product_id': '173372',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 1467,
#   'best_loyalty_price_object': {'amount': '1467', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=0&p=19000016941&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '168841',
#   'sku': '100154-19000008431',
#   'name': 'SHIMMER HIGHLIGHTER ',
#   'brand': 'MORPHE',
#   'brand_type': 'standard',
#   'dimension17': 'Жидкий хайлайтер',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': None,
#   'price': 1097,
#   'price_object': {'amount': '1097', 'currency': 'RUB'},
#   'old_price': 1829,
#   'old_price_object': {'amount': '1829', 'currency': 'RUB'},
#   'category_type': 'Хайлайтер жидкий ',
#   'url': 'https://goldapple.ru/100154-19000008431-shimmer-highlighter',
#   'image_url': 'https://goldapple.ru/media/catalog/product/1/9/192608221670_1_h3i3nz1vo3yeq2h9.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/1/9/192608221670_1_h3i3nz1vo3yeq2h9.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/1/9/192608221670_1_h3i3nz1vo3yeq2h9.jpg',
#    'https://goldapple.ru/media/catalog/product/1/9/192608221670_2_fvqtntbxsylbwfrx.jpg',
#    'https://goldapple.ru/media/catalog/product/1/9/192608221670_3_oi0fzvjziity1esb.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/1/9/192608221670_1_h3i3nz1vo3yeq2h9.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/1/9/192608221670_2_fvqtntbxsylbwfrx.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/1/9/192608221670_3_oi0fzvjziity1esb.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '15',
#   'tone_swatch': 'ENTER GALACTIC ',
#   'labels': [{'code': 'discount',
#     'frontendClass': 'discount',
#     'sortOrder': '2',
#     'fixedPosition': '',
#     'text': '40%',
#     'backgroundColor': '#D1C0B2'},
#    {'code': 'exclusive',
#     'frontendClass': 'exclusive',
#     'sortOrder': '4',
#     'fixedPosition': '',
#     'imageUrl': 'https://goldapple.ru/static/version1656623330/global/images/labels/exclusive.svg',
#     'images': []}],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/1/9/192608221670_1_h3i3nz1vo3yeq2h9.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/1/9/192608221670_1_h3i3nz1vo3yeq2h9.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/1/9/192608221670_1_h3i3nz1vo3yeq2h9.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/1/9/192608221670_1_h3i3nz1vo3yeq2h9.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/1/9/192608221670_1_h3i3nz1vo3yeq2h9.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/1/9/192608221670_1_h3i3nz1vo3yeq2h9.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '19000008431',
#   'main_product_id': '168840',
#   'ga_list_name': '',
#   'adultgood': False,
#   'dimension29': True,
#   'dimension28': True,
#   'dimension26': '40%',
#   'dimension27': 'exclusive',
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=1&p=19000008431&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '210465',
#   'sku': '12147-19760313937',
#   'name': 'Lash Cocoon ',
#   'brand': 'DARLING*',
#   'brand_type': 'standard',
#   'dimension17': 'Универсальная тушь для ресниц',
#   'dimension18': 'Унисекс',
#   'dimension19': None,
#   'dimension20': None,
#   'country': None,
#   'price': 839,
#   'price_object': {'amount': '839', 'currency': 'RUB'},
#   'old_price': 990,
#   'old_price_object': {'amount': '990', 'currency': 'RUB'},
#   'category_type': 'Термотушь 38 °C с эффектом натуральных ресниц ',
#   'url': 'https://goldapple.ru/12147-19760313937-natural-lash-effect-38-c-water-washable-mascara',
#   'image_url': 'https://goldapple.ru/media/catalog/product/8/8/8809738601464_1_rdngl63dwilfkjud.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809738601464_1_rdngl63dwilfkjud.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/8/8/8809738601464_1_rdngl63dwilfkjud.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/8809738601464_2_jfgz1bvkpi0orrgc.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/8809738601464_3_xsrqmk93z2dknod2.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809738601464_1_rdngl63dwilfkjud.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809738601464_2_jfgz1bvkpi0orrgc.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809738601464_3_xsrqmk93z2dknod2.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '8.5',
#   'tone_swatch': '',
#   'labels': [{'code': 'discount',
#     'frontendClass': 'discount',
#     'sortOrder': '2',
#     'fixedPosition': '',
#     'text': '15%',
#     'backgroundColor': '#D1C0B2'},
#    {'code': 'exclusive',
#     'frontendClass': 'exclusive',
#     'sortOrder': '4',
#     'fixedPosition': '',
#     'imageUrl': 'https://goldapple.ru/static/version1656623330/global/images/labels/exclusive.svg',
#     'images': []}],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/8809738601464_1_rdngl63dwilfkjud.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/8809738601464_1_rdngl63dwilfkjud.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/8809738601464_1_rdngl63dwilfkjud.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/8809738601464_1_rdngl63dwilfkjud.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/8809738601464_1_rdngl63dwilfkjud.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/8/8/8809738601464_1_rdngl63dwilfkjud.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '19760313937',
#   'main_product_id': '151008',
#   'ga_list_name': '',
#   'adultgood': False,
#   'dimension29': True,
#   'dimension28': True,
#   'dimension26': '15%',
#   'dimension27': 'exclusive',
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=2&p=19760313937&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '152732',
#   'sku': '19760313783',
#   'name': 'The Eyes & Lips Make Up Remover',
#   'brand': '3INA',
#   'brand_type': 'standard',
#   'dimension17': 'Масло',
#   'dimension18': 'Женский',
#   'dimension19': 'Очищение',
#   'dimension20': 'Лицо',
#   'country': 'Испания',
#   'price': 689,
#   'price_object': {'amount': '689', 'currency': 'RUB'},
#   'old_price': 1155,
#   'old_price_object': {'amount': '1155', 'currency': 'RUB'},
#   'category_type': 'Средство для снятия макияжа с глаз и губ ',
#   'url': 'https://goldapple.ru/19760313783-the-eyes-lips-make-up-remover',
#   'image_url': 'https://goldapple.ru/media/catalog/product/8/4/8435446411653_1_h6xvqz521lup7jbn.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/8/4/8435446411653_1_h6xvqz521lup7jbn.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/8/4/8435446411653_1_h6xvqz521lup7jbn.jpg',
#    'https://goldapple.ru/media/catalog/product/8/4/8435446411653_2_dag1i4kuqmtfixbl.jpg',
#    'https://goldapple.ru/media/catalog/product/8/4/8435446411653_3_bcly2w58tmv1qgmv.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/8/4/8435446411653_1_h6xvqz521lup7jbn.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/4/8435446411653_2_dag1i4kuqmtfixbl.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/4/8435446411653_3_bcly2w58tmv1qgmv.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'simple',
#   'volume': '100',
#   'tone_swatch': '',
#   'labels': [{'code': 'discount',
#     'frontendClass': 'discount',
#     'sortOrder': '2',
#     'fixedPosition': '',
#     'text': '40%',
#     'backgroundColor': '#D1C0B2'}],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/4/8435446411653_1_h6xvqz521lup7jbn.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/4/8435446411653_1_h6xvqz521lup7jbn.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/4/8435446411653_1_h6xvqz521lup7jbn.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/4/8435446411653_1_h6xvqz521lup7jbn.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/4/8435446411653_1_h6xvqz521lup7jbn.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/8/4/8435446411653_1_h6xvqz521lup7jbn.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '19760313783',
#   'main_product_id': '152732',
#   'ga_list_name': '',
#   'adultgood': False,
#   'dimension29': True,
#   'dimension28': False,
#   'dimension26': '40%',
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=3&p=19760313783&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '106370',
#   'sku': '10023-3216800001',
#   'name': 'CABARET PREMIERE ',
#   'brand': 'VIVIENNE SABO',
#   'brand_type': 'standard',
#   'dimension17': 'Объемная тушь для ресниц',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'Франция',
#   'price': 520,
#   'price_object': {'amount': '520', 'currency': 'RUB'},
#   'old_price': 520,
#   'old_price_object': {'amount': '520', 'currency': 'RUB'},
#   'category_type': 'Тушь для ресниц со сценическим эффектом ',
#   'url': 'https://goldapple.ru/10023-3216800001-cabaret-premiere',
#   'image_url': 'https://goldapple.ru/media/catalog/product/3/7/3700971300624_1_es9dyvdjaooeq8r7.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300624_1_es9dyvdjaooeq8r7.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/3/7/3700971300624_1_es9dyvdjaooeq8r7.jpg',
#    'https://goldapple.ru/media/catalog/product/3/7/3700971300624_2_onjujmm1zxviygpt.jpg',
#    'https://goldapple.ru/media/catalog/product/3/7/3700971300624_3_ffvl8cqughazakq7.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300624_1_es9dyvdjaooeq8r7.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300624_2_onjujmm1zxviygpt.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300624_3_ffvl8cqughazakq7.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '9',
#   'tone_swatch': '01 / Черный',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/7/3700971300624_1_es9dyvdjaooeq8r7.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/7/3700971300624_1_es9dyvdjaooeq8r7.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971300624_1_es9dyvdjaooeq8r7.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971300624_1_es9dyvdjaooeq8r7.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971300624_1_es9dyvdjaooeq8r7.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/3/7/3700971300624_1_es9dyvdjaooeq8r7.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '3216800001',
#   'main_product_id': '33214',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 468,
#   'best_loyalty_price_object': {'amount': '468', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=30&p=3216800006&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '144084',
#   'sku': '19760306242',
#   'name': 'Magic Glow GLOW REVITALIZING MASK',
#   'brand': 'DARLING*',
#   'brand_type': 'standard',
#   'dimension17': 'Маски тканевые',
#   'dimension18': 'Унисекс',
#   'dimension19': 'Увлажнение и питание',
#   'dimension20': 'Лицо',
#   'country': None,
#   'price': 199,
#   'price_object': {'amount': '199', 'currency': 'RUB'},
#   'old_price': 199,
#   'old_price_object': {'amount': '199', 'currency': 'RUB'},
#   'category_type': 'Освежающая маска с wow-эффектом cияния',
#   'url': 'https://goldapple.ru/19760306242-magic-glow-facial-treatment',
#   'image_url': 'https://goldapple.ru/media/catalog/product/8/8/8809657114991_1_rvdi8uscvkuxaqfq.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657114991_1_rvdi8uscvkuxaqfq.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/8/8/8809657114991_1_rvdi8uscvkuxaqfq.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/8809657114991_2_88tfa9ijhwx0fcfp.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/8809657114991_3_dh9ncnm7qsfdmepo.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657114991_1_rvdi8uscvkuxaqfq.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657114991_2_88tfa9ijhwx0fcfp.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657114991_3_dh9ncnm7qsfdmepo.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'simple',
#   'volume': '1',
#   'tone_swatch': '',
#   'labels': [{'code': 'exclusive',
#     'frontendClass': 'exclusive',
#     'sortOrder': '4',
#     'fixedPosition': '',
#     'imageUrl': 'https://goldapple.ru/static/version1656623330/global/images/labels/exclusive.svg',
#     'images': []}],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/8809657114991_1_rvdi8uscvkuxaqfq.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/8809657114991_1_rvdi8uscvkuxaqfq.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/8809657114991_1_rvdi8uscvkuxaqfq.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/8809657114991_1_rvdi8uscvkuxaqfq.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/8809657114991_1_rvdi8uscvkuxaqfq.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/8/8/8809657114991_1_rvdi8uscvkuxaqfq.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '19760306242',
#   'main_product_id': '144084',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 179,
#   'best_loyalty_price_object': {'amount': '179', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': True,
#   'dimension27': 'exclusive',
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=5&p=19760306242&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '140608',
#   'sku': '10013-19760306608',
#   'name': 'Futurist Hydra Rescue Moisturizing Makeup',
#   'brand': 'Estée Lauder',
#   'brand_type': 'standard',
#   'dimension17': 'Тональный крем',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'США',
#   'price': 4090,
#   'price_object': {'amount': '4090', 'currency': 'RUB'},
#   'old_price': 4090,
#   'old_price_object': {'amount': '4090', 'currency': 'RUB'},
#   'category_type': 'Увлажняющий тональный крем SPF45',
#   'url': 'https://goldapple.ru/10013-19760306608-futurist-hydra-rescue-moisturizing-makeup-spf45',
#   'image_url': 'https://goldapple.ru/media/catalog/product/8/8/887167466784_1_wrrwoc1mo0pk30j1.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/887167466784_1_wrrwoc1mo0pk30j1.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/8/8/887167466784_1_wrrwoc1mo0pk30j1.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/887167466784_2_jkrzolylvvvkgevx.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/887167466784_3_izvlsdg6r3nc3uo8.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/8/8/887167466784_1_wrrwoc1mo0pk30j1.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/887167466784_2_jkrzolylvvvkgevx.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/887167466784_3_izvlsdg6r3nc3uo8.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '35',
#   'tone_swatch': '1N0 Porcelain',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/887167466784_1_wrrwoc1mo0pk30j1.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/887167466784_1_wrrwoc1mo0pk30j1.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/887167466784_1_wrrwoc1mo0pk30j1.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/887167466784_1_wrrwoc1mo0pk30j1.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/887167466784_1_wrrwoc1mo0pk30j1.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/8/8/887167466784_1_wrrwoc1mo0pk30j1.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '19760306607',
#   'main_product_id': '140606',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 3067,
#   'best_loyalty_price_object': {'amount': '3067', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=83&p=19760306612&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '112936',
#   'sku': '10008-14073800029',
#   'name': 'Hypnose',
#   'brand': 'Lancôme',
#   'brand_type': 'standard',
#   'dimension17': 'Объемная тушь для ресниц',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'Франция',
#   'price': 3080,
#   'price_object': {'amount': '3080', 'currency': 'RUB'},
#   'old_price': 3080,
#   'old_price_object': {'amount': '3080', 'currency': 'RUB'},
#   'category_type': 'Тушь для ресниц',
#   'url': 'https://goldapple.ru/10008-14073800029-hypnose',
#   'image_url': 'https://goldapple.ru/media/catalog/product/3/6/3614272161788_1_yfvgn4k4r383u5yi.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3614272161788_1_yfvgn4k4r383u5yi.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/3/6/3614272161788_1_yfvgn4k4r383u5yi.jpg',
#    'https://goldapple.ru/media/catalog/product/3/6/3614272161788_2_c2pqmtzkgkkopz0k.jpg',
#    'https://goldapple.ru/media/catalog/product/3/6/3614272161788_3_ahmnn36colpfiz5c.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3614272161788_1_yfvgn4k4r383u5yi.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3614272161788_2_c2pqmtzkgkkopz0k.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3614272161788_3_ahmnn36colpfiz5c.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '6,2',
#   'tone_swatch': '01 Noir',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/6/3614272161788_1_yfvgn4k4r383u5yi.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/6/3614272161788_1_yfvgn4k4r383u5yi.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/6/3614272161788_1_yfvgn4k4r383u5yi.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/6/3614272161788_1_yfvgn4k4r383u5yi.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/6/3614272161788_1_yfvgn4k4r383u5yi.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/3/6/3614272161788_1_yfvgn4k4r383u5yi.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '14073800029',
#   'main_product_id': '71234',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 2310,
#   'best_loyalty_price_object': {'amount': '2310', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=7&p=14073800029&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '33207',
#   'sku': '3205400004',
#   'name': 'CABARET',
#   'brand': 'VIVIENNE SABO',
#   'brand_type': 'standard',
#   'dimension17': 'Объемная тушь для ресниц',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'Франция',
#   'price': 444,
#   'price_object': {'amount': '444', 'currency': 'RUB'},
#   'old_price': 444,
#   'old_price_object': {'amount': '444', 'currency': 'RUB'},
#   'category_type': 'Тушь для ресниц с эффектом сценического объёма ',
#   'url': 'https://goldapple.ru/3205400004-cabaret',
#   'image_url': 'https://goldapple.ru/media/catalog/product/3/7/3700971300617_1_z7unfavhmxe9obcv.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300617_1_z7unfavhmxe9obcv.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/3/7/3700971300617_1_z7unfavhmxe9obcv.jpg',
#    'https://goldapple.ru/media/catalog/product/3/7/3700971300617_2_mlfosl6gm6ppd69y.jpg',
#    'https://goldapple.ru/media/catalog/product/3/7/3700971300617_3_sclkxoyg70u23cqa.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300617_1_z7unfavhmxe9obcv.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300617_2_mlfosl6gm6ppd69y.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300617_3_sclkxoyg70u23cqa.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'simple',
#   'volume': '9',
#   'tone_swatch': '01 / Черный',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/7/3700971300617_1_z7unfavhmxe9obcv.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/7/3700971300617_1_z7unfavhmxe9obcv.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971300617_1_z7unfavhmxe9obcv.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971300617_1_z7unfavhmxe9obcv.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971300617_1_z7unfavhmxe9obcv.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/3/7/3700971300617_1_z7unfavhmxe9obcv.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '3205400004',
#   'main_product_id': '33207',
#   'ga_list_name': '',
#   'adultgood': False,
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=9&p=3205400004&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '144085',
#   'sku': '19760306243',
#   'name': 'Recharge CALM-SOOTHE-HYDRATE MASK',
#   'brand': 'DARLING*',
#   'brand_type': 'standard',
#   'dimension17': 'Маски тканевые',
#   'dimension18': 'Унисекс',
#   'dimension19': 'Увлажнение и питание',
#   'dimension20': 'Лицо',
#   'country': None,
#   'price': 199,
#   'price_object': {'amount': '199', 'currency': 'RUB'},
#   'old_price': 199,
#   'old_price_object': {'amount': '199', 'currency': 'RUB'},
#   'category_type': 'Мультимаска с тройным эффектом',
#   'url': 'https://goldapple.ru/19760306243-recharge-natural-fresh-mask',
#   'image_url': 'https://goldapple.ru/media/catalog/product/8/8/8809657115011_1_0ltymv2awsibat84.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657115011_1_0ltymv2awsibat84.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/8/8/8809657115011_1_0ltymv2awsibat84.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/8809657115011_2_tabt2w96yghigntr.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/8809657115011_3_wtanxzhtviqfqre3.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657115011_1_0ltymv2awsibat84.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657115011_2_tabt2w96yghigntr.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657115011_3_wtanxzhtviqfqre3.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'simple',
#   'volume': '1',
#   'tone_swatch': '',
#   'labels': [{'code': 'exclusive',
#     'frontendClass': 'exclusive',
#     'sortOrder': '4',
#     'fixedPosition': '',
#     'imageUrl': 'https://goldapple.ru/static/version1656623330/global/images/labels/exclusive.svg',
#     'images': []}],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/8809657115011_1_0ltymv2awsibat84.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/8809657115011_1_0ltymv2awsibat84.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/8809657115011_1_0ltymv2awsibat84.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/8809657115011_1_0ltymv2awsibat84.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/8809657115011_1_0ltymv2awsibat84.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/8/8/8809657115011_1_0ltymv2awsibat84.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '19760306243',
#   'main_product_id': '144085',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 179,
#   'best_loyalty_price_object': {'amount': '179', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': True,
#   'dimension27': 'exclusive',
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=10&p=19760306243&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '113330',
#   'sku': '10029-3760900014',
#   'name': 'MIRACLE TOUCH',
#   'brand': 'ART-VISAGE',
#   'brand_type': 'standard',
#   'dimension17': 'Консилеры',
#   'dimension18': None,
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'Россия',
#   'price': 307,
#   'price_object': {'amount': '307', 'currency': 'RUB'},
#   'old_price': 307,
#   'old_price_object': {'amount': '307', 'currency': 'RUB'},
#   'category_type': 'Консилер светоотражающий',
#   'url': 'https://goldapple.ru/10029-3760900014-miracle-touch',
#   'image_url': 'https://goldapple.ru/media/catalog/product/4/6/4690327040986_1_lbm678mckhb9qg1j.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/4/6/4690327040986_1_lbm678mckhb9qg1j.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/4/6/4690327040986_1_lbm678mckhb9qg1j.jpg',
#    'https://goldapple.ru/media/catalog/product/4/6/4690327040986_2_19necsvgzbioodho.jpg',
#    'https://goldapple.ru/media/catalog/product/4/6/4690327040986_3_lu7qwmbchxqv6bi5.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/4/6/4690327040986_1_lbm678mckhb9qg1j.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/4/6/4690327040986_2_19necsvgzbioodho.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/4/6/4690327040986_3_lu7qwmbchxqv6bi5.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '6',
#   'tone_swatch': '101',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/4/6/4690327040986_1_lbm678mckhb9qg1j.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/4/6/4690327040986_1_lbm678mckhb9qg1j.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/4/6/4690327040986_1_lbm678mckhb9qg1j.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/4/6/4690327040986_1_lbm678mckhb9qg1j.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/4/6/4690327040986_1_lbm678mckhb9qg1j.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/4/6/4690327040986_1_lbm678mckhb9qg1j.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '3760900014',
#   'main_product_id': '34317',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 276,
#   'best_loyalty_price_object': {'amount': '276', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=92&p=3760900016&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '107851',
#   'sku': '10013-14132800013',
#   'name': 'Double Wear Stay-In-Place Makeup',
#   'brand': 'Estée Lauder',
#   'brand_type': 'standard',
#   'dimension17': 'Тональный крем',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'США',
#   'price': 4090,
#   'price_object': {'amount': '4090', 'currency': 'RUB'},
#   'old_price': 4090,
#   'old_price_object': {'amount': '4090', 'currency': 'RUB'},
#   'category_type': 'Устойчивый тональный крем SPF10',
#   'url': 'https://goldapple.ru/10013-14132800013-double-wear-spf-10',
#   'image_url': 'https://goldapple.ru/media/catalog/product/8/8/887167418103_1_tsnctcgvgw7eooll.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/887167418103_1_tsnctcgvgw7eooll.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/8/8/887167418103_1_tsnctcgvgw7eooll.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/887167418103_2_nekad0r8o0rtfq1y.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/887167418103_3_msmajbqderje1y1x.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/8/8/887167418103_1_tsnctcgvgw7eooll.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/887167418103_2_nekad0r8o0rtfq1y.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/887167418103_3_msmajbqderje1y1x.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '30',
#   'tone_swatch': '1W0 Warm Porcelain',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/887167418103_1_tsnctcgvgw7eooll.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/887167418103_1_tsnctcgvgw7eooll.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/887167418103_1_tsnctcgvgw7eooll.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/887167418103_1_tsnctcgvgw7eooll.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/8/8/887167418103_1_tsnctcgvgw7eooll.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/8/8/887167418103_1_tsnctcgvgw7eooll.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '14132800013',
#   'main_product_id': '78378',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 3067,
#   'best_loyalty_price_object': {'amount': '3067', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=69&p=14132800001&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '115316',
#   'sku': '10023-3210500001',
#   'name': 'FIXATEUR',
#   'brand': 'VIVIENNE SABO',
#   'brand_type': 'standard',
#   'dimension17': 'Гель для бровей',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'Франция',
#   'price': 257,
#   'price_object': {'amount': '257', 'currency': 'RUB'},
#   'old_price': 257,
#   'old_price_object': {'amount': '257', 'currency': 'RUB'},
#   'category_type': 'Фиксирующий гель для бровей и ресниц',
#   'url': 'https://goldapple.ru/10023-3210500001-fixateur',
#   'image_url': 'https://goldapple.ru/media/catalog/product/3/7/3700971300150_1_hooppizbe6ak5ibu.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300150_1_hooppizbe6ak5ibu.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/3/7/3700971300150_1_hooppizbe6ak5ibu.jpg',
#    'https://goldapple.ru/media/catalog/product/3/7/3700971300150_2_ek6cfydphlf9yqn9.jpg',
#    'https://goldapple.ru/media/catalog/product/3/7/3700971300150_3_q37icbkxky9ozxw0.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300150_1_hooppizbe6ak5ibu.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300150_2_ek6cfydphlf9yqn9.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971300150_3_q37icbkxky9ozxw0.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '6',
#   'tone_swatch': 'Clear',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/7/3700971300150_1_hooppizbe6ak5ibu.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/7/3700971300150_1_hooppizbe6ak5ibu.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971300150_1_hooppizbe6ak5ibu.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971300150_1_hooppizbe6ak5ibu.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971300150_1_hooppizbe6ak5ibu.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/3/7/3700971300150_1_hooppizbe6ak5ibu.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '3210500001',
#   'main_product_id': '64950',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 231,
#   'best_loyalty_price_object': {'amount': '231', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=14&p=3210500001&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '144087',
#   'sku': '19760306245',
#   'name': 'Skin Fuel SOOTHING HYDROGEL MASK',
#   'brand': 'DARLING*',
#   'brand_type': 'standard',
#   'dimension17': 'Маски гидрогелевые',
#   'dimension18': 'Унисекс',
#   'dimension19': 'Увлажнение и питание',
#   'dimension20': 'Лицо',
#   'country': None,
#   'price': 299,
#   'price_object': {'amount': '299', 'currency': 'RUB'},
#   'old_price': 299,
#   'old_price_object': {'amount': '299', 'currency': 'RUB'},
#   'category_type': 'Расслабляющая гидрогелевая маска с эффектом моментального восстановления',
#   'url': 'https://goldapple.ru/19760306245-skin-fuel-glowing-hydrogel',
#   'image_url': 'https://goldapple.ru/media/catalog/product/8/8/8809657115172_1_q0hgkze9wbpzuc7p.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657115172_1_q0hgkze9wbpzuc7p.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/8/8/8809657115172_1_q0hgkze9wbpzuc7p.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/8809657115172_2_1a38hbdqdxiypscc.jpg',
#    'https://goldapple.ru/media/catalog/product/8/8/8809657115172_3_e2jgxbasfdg0feys.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657115172_1_q0hgkze9wbpzuc7p.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657115172_2_1a38hbdqdxiypscc.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/8/8/8809657115172_3_e2jgxbasfdg0feys.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'simple',
#   'volume': '1',
#   'tone_swatch': '',
#   'labels': [{'code': 'exclusive',
#     'frontendClass': 'exclusive',
#     'sortOrder': '4',
#     'fixedPosition': '',
#     'imageUrl': 'https://goldapple.ru/static/version1656623330/global/images/labels/exclusive.svg',
#     'images': []}],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/8809657115172_1_q0hgkze9wbpzuc7p.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/8/8/8809657115172_1_q0hgkze9wbpzuc7p.jpg'},
# ...
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/3/3380810269413_3_0ffdumzsszflx2qf.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '8',
#   'tone_swatch': '01',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/3/3380810269413_1_uwnapyfa1cyyjnt7.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/3/3380810269413_1_uwnapyfa1cyyjnt7.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/3/3380810269413_1_uwnapyfa1cyyjnt7.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/3/3380810269413_1_uwnapyfa1cyyjnt7.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/3/3380810269413_1_uwnapyfa1cyyjnt7.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/3/3/3380810269413_1_uwnapyfa1cyyjnt7.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '14012200003',
#   'main_product_id': '104380',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 2625,
#   'best_loyalty_price_object': {'amount': '2625', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=17&p=14012200003&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '197493',
#   'sku': '10002-3108200001',
#   'name': 'Telescopic',
#   'brand': "L'Oreal Paris",
#   'brand_type': 'standard',
#   'dimension17': 'Удлиняющая тушь для ресниц',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'Франция',
#   'price': 766,
#   'price_object': {'amount': '766', 'currency': 'RUB'},
#   'old_price': 766,
#   'old_price_object': {'amount': '766', 'currency': 'RUB'},
#   'category_type': 'Тушь для ресниц',
#   'url': 'https://goldapple.ru/10002-3108200001-telescopic',
#   'image_url': 'https://goldapple.ru/media/catalog/product/3/6/3600521479308_1_w5djbpyehu3rv0h4.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3600521479308_1_w5djbpyehu3rv0h4.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/3/6/3600521479308_1_w5djbpyehu3rv0h4.jpg',
#    'https://goldapple.ru/media/catalog/product/3/6/3600521479308_2_88plrtgznppy8fcw.jpg',
#    'https://goldapple.ru/media/catalog/product/3/6/3600521479308_3_t6qgodfooy67vlto.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3600521479308_1_w5djbpyehu3rv0h4.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3600521479308_2_88plrtgznppy8fcw.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3600521479308_3_t6qgodfooy67vlto.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '8',
#   'tone_swatch': 'Черный',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/6/3600521479308_1_w5djbpyehu3rv0h4.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/6/3600521479308_1_w5djbpyehu3rv0h4.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/6/3600521479308_1_w5djbpyehu3rv0h4.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/6/3600521479308_1_w5djbpyehu3rv0h4.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/6/3600521479308_1_w5djbpyehu3rv0h4.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/3/6/3600521479308_1_w5djbpyehu3rv0h4.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '3108200001',
#   'main_product_id': '197492',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 689,
#   'best_loyalty_price_object': {'amount': '689', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=19&p=3108200001&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '106365',
#   'sku': '10023-3226300001',
#   'name': 'BROW ARCADE SLIM',
#   'brand': 'VIVIENNE SABO',
#   'brand_type': 'standard',
#   'dimension17': 'Карандаш для бровей',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'Франция',
#   'price': 474,
#   'price_object': {'amount': '474', 'currency': 'RUB'},
#   'old_price': 474,
#   'old_price_object': {'amount': '474', 'currency': 'RUB'},
#   'category_type': 'Карандаш для бровей ',
#   'url': 'https://goldapple.ru/10023-3226300001-brow-arcade-slim',
#   'image_url': 'https://goldapple.ru/media/catalog/product/3/7/3700971318223_1_29eqmmvwloljg50y.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971318223_1_29eqmmvwloljg50y.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/3/7/3700971318223_1_29eqmmvwloljg50y.jpg',
#    'https://goldapple.ru/media/catalog/product/3/7/3700971318223_2_cxnscwmixcgz0atx.jpg',
#    'https://goldapple.ru/media/catalog/product/3/7/3700971318223_3_cfikws7h0yasb4ie.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971318223_1_29eqmmvwloljg50y.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971318223_2_cxnscwmixcgz0atx.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/7/3700971318223_3_cfikws7h0yasb4ie.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '0,1',
#   'tone_swatch': '01  Светло-коричневый ',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/7/3700971318223_1_29eqmmvwloljg50y.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/7/3700971318223_1_29eqmmvwloljg50y.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971318223_1_29eqmmvwloljg50y.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971318223_1_29eqmmvwloljg50y.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/7/3700971318223_1_29eqmmvwloljg50y.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/3/7/3700971318223_1_29eqmmvwloljg50y.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '3226300001',
#   'main_product_id': '33103',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 426,
#   'best_loyalty_price_object': {'amount': '426', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=71&p=3226300004&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '113101',
#   'sku': '10024-14053000001',
#   'name': 'Mascara Volume Effet Faux Cils',
#   'brand': 'Yves Saint Laurent ',
#   'brand_type': 'standard',
#   'dimension17': 'Объемная тушь для ресниц',
#   'dimension18': 'Женский',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'Франция',
#   'price': 2980,
#   'price_object': {'amount': '2980', 'currency': 'RUB'},
#   'old_price': 2980,
#   'old_price_object': {'amount': '2980', 'currency': 'RUB'},
#   'category_type': 'Тушь для ресниц',
#   'url': 'https://goldapple.ru/10024-14053000001-mascara-volume-effet-faux-cils',
#   'image_url': 'https://goldapple.ru/media/catalog/product/3/6/3614270455766_1_3rsxf6cexybapqga.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3614270455766_1_3rsxf6cexybapqga.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/3/6/3614270455766_1_3rsxf6cexybapqga.jpg',
#    'https://goldapple.ru/media/catalog/product/3/6/3614270455766_2_ag4fp4detyrglzn4.jpg',
#    'https://goldapple.ru/media/catalog/product/3/6/3614270455766_3_79bxtbbx4ul52ig9.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3614270455766_1_3rsxf6cexybapqga.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3614270455766_2_ag4fp4detyrglzn4.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/3/6/3614270455766_3_79bxtbbx4ul52ig9.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '7.5',
#   'tone_swatch': '01 High Density Black',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/6/3614270455766_1_3rsxf6cexybapqga.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/3/6/3614270455766_1_3rsxf6cexybapqga.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/6/3614270455766_1_3rsxf6cexybapqga.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/6/3614270455766_1_3rsxf6cexybapqga.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/3/6/3614270455766_1_3rsxf6cexybapqga.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/3/6/3614270455766_1_3rsxf6cexybapqga.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '14053000001',
#   'main_product_id': '81454',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 2235,
#   'best_loyalty_price_object': {'amount': '2235', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=21&p=14053000001&rid=msk&mvtId=55814&mvtTs=1656858237280'},
#  {'id': '184546',
#   'sku': '11127-19000029122',
#   'name': 'Moonrise',
#   'brand': 'Lamel Professional',
#   'brand_type': 'standard',
#   'dimension17': 'Жидкая подводка',
#   'dimension18': 'Унисекс',
#   'dimension19': None,
#   'dimension20': None,
#   'country': 'Великобритания',
#   'price': 631,
#   'price_object': {'amount': '631', 'currency': 'RUB'},
#   'old_price': 631,
#   'old_price_object': {'amount': '631', 'currency': 'RUB'},
#   'category_type': 'Цветная стойкая подводка-фломастер для век ',
#   'url': 'https://goldapple.ru/11127-19000029122-moonrise',
#   'image_url': 'https://goldapple.ru/media/catalog/product/5/0/5060805943280_1_orslitmqhnx5midj.jpg',
#   'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/5/0/5060805943280_1_orslitmqhnx5midj.jpg?quality=83',
#   'images': ['https://goldapple.ru/media/catalog/product/5/0/5060805943280_1_orslitmqhnx5midj.jpg',
#    'https://goldapple.ru/media/catalog/product/5/0/5060805943280_2_frasklxsw0bp0hfu.jpg',
#    'https://goldapple.ru/media/catalog/product/5/0/5060805943280_3_jwvf2n6kt2dnowsc.jpg'],
#   'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/5/0/5060805943280_1_orslitmqhnx5midj.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/5/0/5060805943280_2_frasklxsw0bp0hfu.jpg?quality=83',
#    'https://goldapple.ru/web_scripts/webp/catalog/product/5/0/5060805943280_3_jwvf2n6kt2dnowsc.jpg?quality=83'],
#   'is_saleable': True,
#   'type': 'configurable',
#   'volume': '0.6',
#   'tone_swatch': '401, Фиолетовый',
#   'labels': [],
#   'resized_image_url': '',
#   'resized_images': [{'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/5/0/5060805943280_1_orslitmqhnx5midj.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(max-width: 375px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/5/0/5060805943280_1_orslitmqhnx5midj.jpg'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/5/0/5060805943280_1_orslitmqhnx5midj.jpg?quality=83',
#     'type': 'image/webp'},
#    {'media': '(min-width: 376px) and (max-width: 768px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/5/0/5060805943280_1_orslitmqhnx5midj.jpg'},
#    {'media': '(min-width: 769px) and (max-width: 1360px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/5/0/5060805943280_1_orslitmqhnx5midj.jpg'},
#    {'media': '(min-width: 1361px)',
#     'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/5/0/5060805943280_1_orslitmqhnx5midj.jpg'}],
#   'resized_gallery_image_urls': [],
#   'resized_gallery_images': [],
#   'need_render_old_price': True,
#   'main_product_sku': '19000029122',
#   'main_product_id': '184533',
#   'ga_list_name': '',
#   'adultgood': False,
#   'best_loyalty_price': 567,
#   'best_loyalty_price_object': {'amount': '567', 'currency': 'RUB'},
#   'dimension29': False,
#   'dimension28': False,
#   'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&bfstid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=29&p=19000029123&rid=msk&mvtId=55814&mvtTs=1656858237280'}]

# %%
old = {'id': '173372',
  'sku': '19000016941',
  'name': 'К122',
  'brand': 'Manly PRO',
  'brand_type': 'standard',
  'dimension17': 'Кисти для лица',
  'dimension18': 'Женский',
  'dimension19': None,
  'dimension20': None,
  'country': 'Россия',
  'price': 1630,
  'price_object': {'amount': '1630', 'currency': 'RUB'},
  'old_price': 1630,
  'old_price_object': {'amount': '1630', 'currency': 'RUB'},
       'category_type': 'Большая плоская кисть для пудры ',
  'url': 'https://goldapple.ru/19000016941-k122',
  'image_url': 'https://goldapple.ru/media/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg',
  'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
  'images': ['https://goldapple.ru/media/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg',
   'https://goldapple.ru/media/catalog/product/6/9/6921166812419_2_chfmwll08kkefjw8.jpg',
   'https://goldapple.ru/media/catalog/product/6/9/6921166812419_3_3apxe5hspdnd5it6.jpg'],
  'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
   'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_2_chfmwll08kkefjw8.jpg?quality=83',
   'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_3_3apxe5hspdnd5it6.jpg?quality=83'],
  'is_saleable': True,
  'type': 'simple',
  'volume': '1',
       'best_loyalty_price': 1467,
  'best_loyalty_price_object': {'amount': '1467', 'currency': 'RUB'},
  'dimension29': False,
  'dimension28': False,
  'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=8c855a7d-b5fe-418c-a4db-6060711c8360&stid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=0&p=19000016941&rid=msk&mvtId=55814&mvtTs=1656858237280',
       'resized_gallery_images': [],
  'need_render_old_price': True,
  'main_product_sku': '19000016941',
  'main_product_id': '173372',}

fields = [
        'id',
        'sku',
        'name',
        'brand',
        'brand_type',
        'dimension17',
        'dimension18',
        'dimension19',
        'dimension20',
        'country',
        'price',
        'old_price',
        'category_type',
        'url',
        'images',
        'type',
        'volume',
        'main_product_sku',
        'main_product_id',
        'best_loyality_price',
        'dimension29',
        'dimension28',
        'description',
        'product_usage',
        'product_composition',
        'category',
        'category_ru'
        ]

dict_you_want = {your_key: old[your_key] if your_key in old.keys() else None  for your_key in fields }
dict_you_want
# Out:
# {'id': '173372',
#  'sku': '19000016941',
#  'name': 'К122',
#  'brand': 'Manly PRO',
#  'brand_type': 'standard',
#  'dimension17': 'Кисти для лица',
#  'dimension18': 'Женский',
#  'dimension19': None,
#  'dimension20': None,
#  'country': 'Россия',
#  'price': 1630,
#  'old_price': 1630,
#  'category_type': 'Большая плоская кисть для пудры ',
#  'url': 'https://goldapple.ru/19000016941-k122',
#  'images': ['https://goldapple.ru/media/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg',
#   'https://goldapple.ru/media/catalog/product/6/9/6921166812419_2_chfmwll08kkefjw8.jpg',
#   'https://goldapple.ru/media/catalog/product/6/9/6921166812419_3_3apxe5hspdnd5it6.jpg'],
#  'type': 'simple',
#  'volume': '1',
#  'main_product_sku': '19000016941',
#  'main_product_id': '173372',
#  'best_loyality_price': None,
#  'dimension29': False,
#  'dimension28': False,
#  'description': None,
#  'product_usage': None,
#  'product_composition': None,
#  'category': None,
#  'category_ru': None}

# %%
product_template = {
    'id': None,
    'sku': None,
    'name': None,
    'brand': None,
    'brand_type': None,
    'dimension17': None,
    'dimension18': None,
    'dimension19': None,
    'dimension20': None,
    'country': None,
    'price': None,
    'currency': None,
    'old_price': None,
    'category_type': None,
    'url': None,
    'images': None,
    'type': None,
    'volume': None,
    'main_product_sku': None,
    'main_product_id': None,
    'best_loyality_price': None,
    'dimension29': None,
    'dimension28': None,
    'description': None,
    'product_usage': None,
    'product_composition': None,
    'category': None,
    'category_ru': None
}

# %%
len(cat_urls)
# Out:
# 10359

# %%
counter = 0
for url in cat_urls:
    url = url.split('https://goldapple.ru/')[1].split('/')
    print(url)
    counter += 1
    # if counter > 20:
    #     break
# Out:
# ['uhod']
# ['volosy']
# ['parfjumerija']
# ['aksessuary']
# ['azija']
# ['organika']
# ['makijazh', 'lico']
# ['makijazh', 'glaza']
# ['makijazh', 'guby']
# ['makijazh', 'brovi']
# ['makijazh', 'nogti']
# ['makijazh', 'kisti']
# ['makijazh', 'paletki']
# ['makijazh', 'nabory']
# ['makijazh', 'aksessuary']
# ['makijazh', 'detjam']
# ['uhod', 'uhod-za-licom']
# ['uhod', 'uhod-za-telom']
# ['uhod', 'nabory']
# ['volosy', 'shampun']
# ['volosy', 'kondicioner']
# ['volosy', 'suhoj-shampun']
# ['volosy', 'uhod-za-volosami']
# ['volosy', 'stajling']
# ['volosy', 'aksessuary']
# ['volosy', 'okrashivanie']
# ['volosy', 'dlja-stilistov']
# ['parfjumerija', 'zhenskie-aromaty-parfume']
# ['parfjumerija', 'muzhskie-aromaty']
# ['parfjumerija', 'nishevaja-parfjumerija']
# ['parfjumerija', 'aromaty-dlja-doma']
# ['parfjumerija', 'nabory']
# ['parfjumerija', 'aksessuary']
# ['aksessuary', 'dlja-vizazhistov']
# ['azija', 'makijazh']
# ['catalog', 'category', 'view', 'id', '82']
# ['organika', 'volosy']
# ['makijazh', 'lico', 'prajmery']
# ['makijazh', 'lico', 'tonal-nye-sredstva']
# ['makijazh', 'lico', 'korrektory-i-kosilery']
# ['makijazh', 'lico', 'bronzering-i-konturing']
# ['makijazh', 'lico', 'fiksatory-dlja-makijazha']
# ['makijazh', 'lico', 'pudra']
# ['makijazh', 'lico', 'rumjana']
# ['makijazh', 'lico', 'hajlajtery']
# ['makijazh', 'glaza', 'baza-dlja-makijazha']
# ['makijazh', 'glaza', 'podvodka']
# ['makijazh', 'glaza', 'glitter']
# ['makijazh', 'glaza', 'karandash-dlja-glaz']
# ['makijazh', 'glaza', 'nakladnye-resnicy']
# ['makijazh', 'glaza', 'teni-dlja-vek']
# ['makijazh', 'glaza', 'tush-dlja-resnic']
# ['makijazh', 'guby', 'baza-dlja-gub']
# ['makijazh', 'guby', 'gubnaja-pomada']
# ['makijazh', 'guby', 'blesk-dlja-gub']
# ['makijazh', 'guby', 'karandash-dlja-gub']
# ['makijazh', 'guby', 'uhod-dlja-gub']
# ['makijazh', 'brovi', 'gel-dlja-brovej']
# ['makijazh', 'brovi', 'karandash-dlja-brovej']
# ['makijazh', 'brovi', 'teni-dlja-brovej']
# ['makijazh', 'brovi', 'tush-dlja-brovej']
# ['makijazh', 'nogti', 'lak-dlja-nogtej']
# ['makijazh', 'nogti', 'baza-i-top']
# ['makijazh', 'nogti', 'sredstva-dlja-snjatija-laka']
# ['makijazh', 'nogti', 'dlja-manikjura']
# ['makijazh', 'kisti', 'dlja-lica']
# ['makijazh', 'kisti', 'dlja-glaz']
# ['makijazh', 'kisti', 'dlja-gub']
# ['makijazh', 'kisti', 'sredstva-dlja-ochistki-kistej']
# ['makijazh', 'kisti', 'nabory-kistej']
# ['makijazh', 'paletki', 'dlja-lica']
# ['makijazh', 'paletki', 'dlja-glaz']
# ['makijazh', 'paletki', 'dlja-gub']
# ['makijazh', 'nabory', 'podarochnye-nabory']
# ['makijazh', 'detjam', 'guby']
# ['makijazh', 'detjam', 'nogti']
# ['makijazh', 'detjam', 'nabory']
# ['uhod', 'uhod-za-licom', 'ochischenie-i-demakijazh']
# ['uhod', 'uhod-za-licom', 'osnovnoj-uhod']
# ['uhod', 'uhod-za-licom', 'special-nyj-uhod']
# ['uhod', 'uhod-za-licom', 'antivozrastnoj-uhod-za-licom']
# ['uhod', 'uhod-za-licom', 'syvorotki']
# ['uhod', 'uhod-za-licom', 'maski']
# ['uhod', 'uhod-za-licom', 'detskij-uhod']
# ['uhod', 'uhod-za-telom', 'osnovnoj-uhod']
# ['uhod', 'uhod-za-telom', 'dlja-dusha-i-vanny']
# ['uhod', 'uhod-za-telom', 'dezodoranty']
# ['uhod', 'uhod-za-telom', 'anticelljulitnye-i-korrektirujuschie-sredstva']
# ['uhod', 'uhod-za-telom', 'detskij-uhod']
# ['uhod', 'uhod-za-polost-ju-rta']
# ['uhod', 'uhod-za-telom', 'dlja-ruk']
# ['uhod', 'uhod-za-telom', 'dlja-nog']
# ['uhod', 'solnechnaja-linija']
# ['uhod', 'uhod-za-telom', 'lichnaja-gigiena']
# ['volosy', 'uhod-za-volosami', 'maski']
# ['volosy', 'uhod-za-volosami', 'skraby']
# ['volosy', 'uhod-za-volosami', 'maslo']
# ['volosy', 'uhod-za-volosami', 'special-nyj-uhod']
# ['volosy', 'stajling', 'lak-dlja-volos']
# ['volosy', 'stajling', 'pudra-dlja-volos']
# ['volosy', 'stajling', 'gel-dlja-volos']
# ['volosy', 'stajling', 'vosk-dlja-volos']
# ['volosy', 'stajling', 'pasta-dlja-volos']
# ['volosy', 'stajling', 'termozaschita']
# ['volosy', 'stajling', 'penka']
# ['volosy', 'stajling', 'teksturirujuschie-sredstva']
# ['volosy', 'stajling', 'muzhskoj-stajling']
# ['volosy', 'aksessuary', 'rascheski']
# ['volosy', 'aksessuary', 'rezinki']
# ['volosy', 'aksessuary', 'zakolki']
# ['volosy', 'aksessuary', 'shpil-ki-i-nevidimki']
# ['volosy', 'aksessuary', 'feny']
# ['volosy', 'aksessuary', 'schipcy']
# ['volosy', 'aksessuary', 'utjuzhki-dlja-volos']
# ['volosy', 'okrashivanie', 'kraska-dlja-volos']
# ['volosy', 'okrashivanie', 'tonirovanie']
# ['volosy', 'dlja-stilistov', 'shampun']
# ['volosy', 'dlja-stilistov', 'kondicioner']
# ['volosy', 'dlja-stilistov', 'maski']
# ['volosy', 'dlja-stilistov', 'maslo']
# ['volosy', 'dlja-stilistov', 'uhod-dlja-volos']
# ['parfjumerija', 'nishevaja-parfjumerija', 'bannaja-linija']
# ['parfjumerija', 'aromaty-dlja-doma', 'aromaticheskie-svechi']
# ['parfjumerija', 'aromaty-dlja-doma', 'diffuzory']
# ['parfjumerija', 'aromaty-dlja-doma', 'sashe']
# ['parfjumerija', 'aromaty-dlja-doma', 'nabory']
# ['parfjumerija', 'aksessuary', 'smennyj-blok']
# ['parfjumerija', 'aksessuary', 'smennyj-flakon']
# ['azija', 'makijazh', 'dlja-lica']
# ['azija', 'makijazh', 'dlja-glaz']
# ['azija', 'makijazh', 'dlja-gub']
# ['azija', 'makijazh', 'dlja-manikjura']
# ['azija', 'volosy', 'shampun']
# ['azija', 'volosy', 'kondicioner']
# ['azija', 'volosy', 'special-nyj-uhod']
# ['organika', 'volosy', 'shampun']
# ['organika', 'volosy', 'kondicioner']
# ['parfjumerija', 'aksessuary', 'chehly']
# ['catalog', 'category', 'view', 'id', '763']
# ['brands', 'mac']
# ['brands', 'kenzo']
# ['brands', 'kenzo', 'zhenskaja-parfjumerija']
# ['brands', 'make-up-for-ever-brand']
# ['brands', 'make-up-for-ever-brand', 'novinki']
# ['brands', 'make-up-for-ever-brand', 'bestsellery']
# ['brands', 'make-up-for-ever-brand', 'lico']
# ['brands', 'kenzo', 'muzhskaja-parfjumerija']
# ['brands', 'kenzo', 'uhod-kenzoki']
# ['brands', 'biotherm']
# ['brands', 'bobbi-brown']
# ['brands', 'clinique']
# ['brands', 'donna-karan']
# ['brands', 'glamglow']
# ['brands', 'lancome']
# ['brands', 'yves-saint-laurent']
# ['brands', 'biotherm', 'ochischenie']
# ['brands', 'biotherm', 'anti-vozrastnoj-uhod']
# ['brands', 'biotherm', 'uvlazhnenie-i-vosstanovlenie']
# ['brands', 'biotherm', 'uhod-dlja-tela']
# ['brands', 'biotherm', 'dlja-muzhchin']
# ['brands', 'aveda-brand']
# ['brands', 'lancome', 'makijazh']
# ['brands', 'lancome', 'uhod']
# ['brands', 'lancome', 'parfjumerija']
# ['azija', 'makijazh', 'brovi']
# ['brands', 'giorgio-armani-brand']
# ['brands', 'make-up-for-ever-brand', 'glaza']
# ['brands', 'make-up-for-ever-brand', 'guby']
# ['brands', 'make-up-for-ever-brand', 'demakijazh']
# ['brands', 'make-up-for-ever-brand', 'kisti']
# ['brands', 'make-up-for-ever-brand', 'aksessuary']
# ['brands', 'clarins']
# ['organika', 'uhod']
# ['organika', 'uhod', 'uhod-dlja-lica']
# ['organika', 'uhod', 'uhod-dlja-tela']
# ['organika', 'uhod', 'nabory']
# ['organika', 'volosy', 'uhod-dlja-volos']
# ['azija', 'uhod']
# ['azija', 'uhod', 'uhod-dlja-lica']
# ['azija', 'uhod', 'uhod-dlja-tela']
# ['volosy', 'nabory']
# ['brands', 'guerlain']
# ['brands', 'la-mer']
# ['brands', 'cacharel']
# ['brands', 'estee-lauder']
# ['brands', 'helena-rubinstein']
# ['brands', 'narciso-rodriguez']
# ['aksessuary', 'kisti']
# ['aksessuary', 'kisti', 'dlja-lica']
# ['aksessuary', 'kisti', 'dlja-glaz']
# ['aksessuary', 'kisti', 'dlja-gub']
# ['aksessuary', 'kisti', 'sredstva-dlja-ochistki-kistej']
# ['aksessuary', 'kisti', 'nabory-kistej']
# ['brands', 'guerlain', 'zhenskaja-parfjumerija']
# ['brands', 'guerlain', 'muzhskaja-parfjumerija']
# ['brands', 'guerlain', 'makijazh']
# ['brands', 'guerlain', 'uhod-za-kozhej']
# ['brands', 'guerlain', 'novinki']
# ['brands', 'guerlain', 'bestsellery']
# ['brands', 'clarins', 'novinki']
# ['brands', 'clarins', 'uhod-za-licom']
# ['brands', 'clarins', 'uhod-za-telom']
# ['brands', 'clarins', 'makijazh']
# ['brands', 'by-kilian']
# ['azija', 'aksessuary']
# ['brands', 'aveda-brand', 'volosy']
# ['brands', 'aveda-brand', 'zvezdnye-produkty']
# ['brands', 'aveda-brand', 'makijazh']
# ['brands', 'aveda-brand', 'uhod-dlja-kozhi-golovy']
# ['brands', 'aveda-brand', 'uhod-dlja-lica']
# ['catalog', 'category', 'view', 'id', '941']
# ['brands', 'anne-semonin']
# ['brands', 'viktor-rolf']
# ['brands', 'tom-ford']
# ['brands', 'frederic-malle']
# ['brands', 'yves-saint-laurent', 'aromaty']
# ['brands', 'yves-saint-laurent', 'makijazh']
# ['brands', 'yves-saint-laurent', 'uhod']
# ['brands', 'giorgio-armani', 'makijazh']
# ['brands', 'giorgio-armani', 'aromaty']
# ['brands', 'la-mer', 'ins']
# ['brands', 'giorgio-armani', 'uhod']
# ['brands', 'giorgio-armani', 'armani-prive']
# ['brands', 'frederic-malle', 'ins']
# ['brands', 'glamglow', 'maski']
# ['brands', 'glamglow', 'uhod-za-kozhej']
# ['brands', 'glamglow', 'ochischenie']
# ['brands', 'glamglow', 'makijazh']
# ['brands', 'la-mer', 'uhod']
# ['brands', 'la-mer', 'makijazh']
# ['brands', 'tommy-hilfiger']
# ['brands', 'frederic-malle', 'travel-size']
# ['brands', 'l-oreal-paris']
# ['brands', 'anne-semonin', 'intensivnye-kompleksy']
# ['brands', 'viktor-rolf', 'dlja-nejo']
# ['brands', 'viktor-rolf', 'dlja-nego']
# ['brands', 'yves-saint-laurent', 'novinki']
# ['brands', 'anne-semonin', 'uhod-za-telom']
# ['brands', 'darphin']
# ['brands', 'darphin', 'aromaticheskie-jeliksiry']
# ['brands', 'darphin', 'ochischenie-i-special-nyj-uhod']
# ['brands', 'darphin', 'uhod-za-glazami']
# ['brands', 'darphin', 'uhod-za-telom-i-solncezaschitnyj-uhod']
# ['brands', 'giorgio-armani', 'makijazh', 'guby']
# ['brands', 'giorgio-armani', 'makijazh', 'glaza']
# ['brands', 'l-oreal-paris', 'makijazh']
# ['brands', 'l-oreal-paris', 'lico']
# ['brands', 'l-oreal-paris', 'makijazh', 'guby']
# ['brands', 'l-oreal-paris', 'glaza']
# ['brands', 'l-oreal-paris', 'uhod']
# ['brands', 'l-oreal-paris', 'kraski-dlja-volos']
# ['brands', 'giorgio-armani', 'makijazh', 'aksessuary']
# ['brands', 'l-oreal-paris', 'novinki']
# ['brands', 'l-oreal-paris', 'bestsellery']
# ['brands', 'giorgio-armani', 'aromaty', 'muzhskaja-parfjumerija']
# ['brands', 'giorgio-armani', 'aromaty', 'zhenskaja-parfjumerija']
# ['brands', 'narciso-rodriguez', 'zhenskaja-parfjumerija']
# ['brands', 'yves-saint-laurent', 'aromaty', 'aromaty-dlja-nee']
# ['brands', 'yves-saint-laurent', 'aromaty', 'aromaty-dlja-nego']
# ['brands', 'yves-saint-laurent', 'makijazh', 'lico']
# ['brands', 'yves-saint-laurent', 'makijazh', 'glaza']
# ['brands', 'yves-saint-laurent', 'makijazh', 'guby']
# ['brands', 'urban-decay', 'paletki']
# ['brands', 'urban-decay', 'glaza']
# ['brands', 'urban-decay', 'guby']
# ['brands', 'urban-decay', 'lico']
# ['brands', 'paco-rabanne']
# ['brands', 'la-mer', 'uvlazhnjajuschaja-kollekcija']
# ['brands', 'lancome', 'novinki']
# ['brands', 'helena-rubinstein', 'uhod']
# ['brands', 'helena-rubinstein', 'makijazh']
# ['brands', 'helena-rubinstein', 're-plasty']
# ['brands', 'helena-rubinstein', 'prodigy-reversis']
# ['brands', 'helena-rubinstein', 'powercell']
# ['brands', 'helena-rubinstein', 'force-c']
# ['brands', 'helena-rubinstein', 'collagenist']
# ['brands', 'helena-rubinstein', 'dlja-glaz']
# ['brands', 'helena-rubinstein', 'dlja-lica']
# ['brands', 'helena-rubinstein', 'dlja-gub']
# ['brands', 'sisley']
# ['brands', 'sisley', 'lico']
# ['brands', 'sisley', 'makijazh']
# ['brands', 'sisley', 'aromaty']
# ['brands', 'sisley', 'novinki-i-bestsellery']
# ['brands', 'sisley', 'volosy']
# ['brands', 'sisley', 'rekomenduem']
# ['uhod', 'uhod-za-licom', 'uhod-dlja-gub']
# ['brands', 'narciso-rodriguez', 'muzhskaja-parfjumerija']
# ['brands', 'creed']
# ['brands', 'philips']
# ['brands', 'adidas']
# ['brands', 'andrea']
# ['brands', 'secret']
# ['brands', 'duo']
# ['brands', 'gucci']
# ['brands', 'bell']
# ['brands', 'funs']
# ['brands', 'expert-professional']
# ['brands', 'always']
# ['brands', 'matrix']
# ['brands', 'braun']
# ['brands', 'eos']
# ['brands', 'clear']
# ['catalog', 'category', 'view', 'id', '1111']
# ['brands', 'attack']
# ['brands', 'tf-cosmetics']
# ['brands', 'fa']
# ['brands', 'estel']
# ['brands', 'essence']
# ['brands', 'nyx-professional-makeup']
# ['brands', 'calvin-klein']
# ['brands', 'aura']
# ['brands', 'glamglow', 'mini-formaty']
# ['brands', 'givenchy']
# ['brands', 'balenciaga']
# ['brands', 'chloe']
# ['brands', 'o-b']
# ['brands', 'dove']
# ['brands', 'roland']
# ['brands', 'prada']
# ['brands', 'lacoste']
# ['brands', 'johnson-johnson']
# ['brands', 'hugo-boss']
# ['brands', 'cartier']
# ['brands', 'president']
# ['brands', 'oral-b']
# ['brands', 'versace']
# ['brands', 'teana-laboratories']
# ['brands', 'maybelline-new-york']
# ['brands', 'la-roche-posay']
# ['brands', 'gillette']
# ['brands', 'durex']
# ['brands', 'ollin-professional']
# ['brands', 'wella']
# ['brands', 'chernyj-zhemchug']
# ['brands', 'seventeen']
# ['brands', 'valentino']
# ['brands', 'r-o-c-s']
# ['brands', 'catrice']
# ['brands', 'natura-siberica']
# ['brands', 'shiseido']
# ['brands', 'axe']
# ['brands', 'benetton']
# ['brands', 'elizavecca']
# ['brands', 'garnier']
# ['brands', 'bvlgari']
# ['brands', 'moschino']
# ['brands', 'cottage']
# ['brands', 'missha']
# ['brands', 'luke']
# ['brands', 'vivienne-sabo']
# ['brands', 'syoss']
# ['brands', 'styx-naturcosmetic']
# ['brands', 'riche']
# ['brands', 'pupa']
# ['brands', 'loewe']
# ['brands', 'holika-holika']
# ['brands', 'tony-moly']
# ['brands', 'marc-jacobs']
# ['brands', 'byredo']
# ['brands', 'weleda']
# ['brands', 'mexx']
# ['brands', 'escada']
# ['brands', 'carolina-herrera']
# ['brands', 'bioderma']
# ['brands', 'tresemme']
# ['brands', 'constant-delight']
# ['brands', 'pigeon']
# ['brands', 'the-saem']
# ['brands', 'memo-paris']
# ['brands', 'contex']
# ['brands', 'mizon']
# ['brands', 'bourjois']
# ['brands', 'revlon']
# ['brands', 'librederm']
# ['brands', 'max-factor']
# ['brands', 'organic-shop']
# ['brands', 'dnc-kosmetika']
# ['brands', 'palmer-s']
# ['brands', 'kerastase']
# ['brands', 'payot']
# ['brands', 'secret-key']
# ['brands', 'anny']
# ['brands', 'l-occitane']
# ['brands', 'redken']
# ['brands', 'ex-nihilo']
# ['brands', 'uriage']
# ['brands', 'amouage']
# ['brands', 'belka']
# ['brands', 'sleek']
# ['brands', 'lador']
# ['brands', 'miriam-quevedo']
# ['brands', 'divage']
# ['brands', 'nina-ricci']
# ['brands', 'lancaster']
# ['brands', 'widian']
# ['brands', 'davines']
# ['brands', 'zinger']
# ['brands', 'petitfee']
# ['brands', 'mancera']
# ['brands', 'guam']
# ['catalog', 'category', 'view', 'id', '1224']
# ['brands', 'antonio-banderas']
# ['brands', 'cerave']
# ['brands', 'proffs']
# ['brands', 'head-shoulders']
# ['brands', 'shaik']
# ['brands', 'tangle-teezer']
# ['brands', 'artdeco']
# ['brands', 'rimmel']
# ['brands', 'recepty-babushki-agaf-i']
# ['brands', 'gosh']
# ['brands', 'davidoff']
# ['brands', 'system-4']
# ['brands', 'miu-miu']
# ['brands', 'levrana']
# ['brands', 'manly-pro']
# ['brands', 'limoni']
# ['brands', 'libero']
# ['brands', 'veet']
# ['brands', 'etro']
# ['brands', 'splat']
# ['brands', 'escentric-molecule']
# ['brands', 'revolution-makeup']
# ['brands', 'barhatnye-ruchki']
# ['brands', 'colgate']
# ['brands', 'bottega-veneta']
# ['brands', 'cutrin']
# ['brands', 'caudalie']
# ['brands', 'roberto-cavalli']
# ['brands', 'curaprox']
# ['brands', 'serge-lutens']
# ['brands', 'lime-crime']
# ['brands', 'isadora']
# ['brands', 'indola']
# ['brands', 'juicy-couture']
# ['brands', 'art-visage']
# ['brands', 'paese']
# ['brands', 'kora']
# ['brands', 'ducray']
# ['brands', 'sativa']
# ['brands', 'wella-professionals']
# ['brands', 'american-crew']
# ['brands', 'farm-stay']
# ['catalog', 'category', 'view', 'id', '1273']
# ['brands', 'the-skin-house']
# ['brands', 'lesnoj-bal-zam']
# ['brands', 'bergamo']
# ['brands', 'planeta-organica']
# ['brands', 'skinlite']
# ['brands', 'procter-gamble']
# ['catalog', 'category', 'view', 'id', '1283']
# ['brands', 'mi-ko']
# ['brands', 'olaplex']
# ['brands', 'armand-basi']
# ['brands', 'mugler']
# ['brands', 'atelier-cologne']
# ['brands', 'ahava']
# ['brands', 'biore']
# ['brands', 'alterna']
# ['brands', 'acqua-di-parma']
# ['brands', 'chupa-chups']
# ['brands', 'romanovamakeup']
# ['brands', 'smith-cult']
# ['brands', 'eau-thermale-avene']
# ['brands', 'ga-de']
# ['brands', 'wet-n-wild']
# ['brands', 'elizabeth-arden']
# ['catalog', 'category', 'view', 'id', '1302']
# ['brands', 'londa-professional']
# ['brands', 'essie']
# ['brands', 'physician-s-formula']
# ['brands', 'finesse']
# ['brands', 'colorista']
# ['brands', 'old-spice']
# ['brands', 'lakme']
# ['brands', 'hask']
# ['brands', 'elseve']
# ['brands', 'sally-hansen']
# ['brands', 'issey-miyake']
# ['brands', 'juliette-has-a-gun']
# ['catalog', 'category', 'view', 'id', '1317']
# ['brands', 'cj-lion']
# ['brands', 'tigi-bed-head']
# ['brands', 'himalaya-herbals']
# ['brands', 'la-miso']
# ['brands', 'oribe']
# ['brands', 'bruno-banani']
# ['brands', 'pantene']
# ['brands', 'got2b']
# ['catalog', 'category', 'view', 'id', '1327']
# ['brands', 'missoni']
# ['brands', 'betty-barclay']
# ['brands', 'floresan-cosmetic']
# ['brands', 'it-s-skin']
# ['brands', 'taft']
# ['brands', 'valmont']
# ['brands', 'neutrogena']
# ['brands', 'batiste']
# ['brands', 'ciracle']
# ['catalog', 'category', 'view', 'id', '1338']
# ['brands', 'nouba']
# ['brands', 'gliss-kur']
# ['brands', 'maison-francis-kurkdjian']
# ['brands', 'ermenegildo-zegna']
# ['brands', 'anskin']
# ['brands', 'bio-repair']
# ['brands', 'john-frieda']
# ['brands', 'green-mama']
# ['brands', 'berrisom']
# ['brands', 'korres']
# ['brands', 'rexaline']
# ['brands', 'eunyul']
# ['brands', 'shary']
# ['brands', 'klorane']
# ['brands', 'joop']
# ['brands', 'john-varvatos']
# ['brands', 'initio-parfums-prives']
# ['brands', 'rexona']
# ['brands', 'estrade']
# ['brands', 'diptyque']
# ['brands', 'safeguard']
# ['brands', '3lab']
# ['brands', 'dr-hauschka']
# ['brands', 'angel-schlesser']
# ['brands', 'botavikos']
# ['brands', 'bio-oil']
# ['catalog', 'category', 'view', 'id', '1367']
# ['brands', 'ninelle']
# ['brands', 'proraso']
# ['brands', 'dorco']
# ['brands', 'lacalut']
# ['brands', '4-skin']
# ['brands', 'lee-stafford']
# ['brands', 'thalgo']
# ['brands', 'be-yu']
# ['brands', 'orthia']
# ['brands', 'koelf']
# ['brands', 'franck-boclet']
# ['brands', 'sosu']
# ['brands', 'savonry']
# ['brands', 'palmolive']
# ['brands', 'm-micallef']
# ['brands', 'jigott']
# ['brands', 'real-techniques']
# ['brands', 'belita']
# ['brands', 'st-moriz']
# ['brands', 'skin79']
# ['brands', 'matis']
# ['brands', 'sensodyne']
# ['brands', 'japan-gals']
# ['brands', 'invisibobble']
# ['brands', 'mise-en-scene']
# ['brands', 'nesti-dante']
# ['brands', 'etude-organix']
# ['brands', 'sim-sensitive']
# ['brands', 'listerine']
# ['brands', 'naturella']
# ['brands', 'royal-skin']
# ['brands', '100-receptov-krasoty']
# ['brands', 'james-read']
# ['brands', 'solomeya']
# ['brands', 'blithe']
# ['brands', 'label-m']
# ['brands', 'marina-de-bourbon']
# ['brands', 'carefree']
# ['brands', 'sorme']
# ['brands', 'milv']
# ['brands', 'laboratorium']
# ['brands', 'parfums-de-marly']
# ['brands', 'frudia']
# ['brands', 'marvis']
# ['brands', 'purederm']
# ['brands', 'naillook']
# ['catalog', 'category', 'view', 'id', '1434']
# ['brands', 'double-dare-omg']
# ['brands', 'cettua']
# ['brands', 'vichy']
# ['brands', 'beauty-blender']
# ['makijazh']
# ['brands', 'urban-decay']
# ['uhod', 'uhod-za-licom', 'patchi']
# ['azija', 'patchi']
# ['brands', 'maybelline-new-york', 'lico']
# ['brands', 'maybelline-new-york', 'guby']
# ['brands', 'maybelline-new-york', 'glaza']
# ['brands', 'sensay']
# ['brands', 'david-beckham']
# ['brands', 'mixit']
# ['brands', 'nyx-professional-makeup', 'guby']
# ['brands', 'nyx-professional-makeup', 'glaza']
# ['brands', 'nyx-professional-makeup', 'lico']
# ['brands', 'nyx-professional-makeup', 'paletki']
# ['brands', '4711-acqua-colonia']
# ['brands', 'trolli']
# ['brands', 'lei']
# ['brands', 'gadkij-ja']
# ['brands', 'schwarzkopf-professional']
# ['brands', 'ogx']
# ['brands', 'clubman']
# ['brands', 'swiss-image']
# ['brands', 'qvs']
# ['brands', 'saraya']
# ['brands', 'blend-a-med']
# ['brands', 'lirene']
# ['brands', 'nagara']
# ['brands', 'longa-vita']
# ['brands', 'bell-hypoallergenic']
# ['brands', 'swiss-line']
# ['brands', 'the-merchant-of-venice']
# ['brands', 'secret-nature']
# ['brands', 'inm']
# ['brands', 'parodontax']
# ['brands', 'sophin']
# ['brands', 'lucas-cosmetics']
# ['brands', 'kiss-new-york-professional']
# ['brands', 'blanx']
# ['brands', 'camay']
# ['brands', 'the-house-of-oud']
# ['brands', 'estelare']
# ['brands', 'cotton-club']
# ['brands', 'inoface']
# ['brands', 'blistex']
# ['brands', 'pure-paw-paw']
# ['brands', 'cellcosmet']
# ['brands', 'l-sanic']
# ['brands', 'kidstaff']
# ['brands', 'janeke']
# ['brands', 'omorovicza']
# ['brands', 'mama-comfort']
# ['catalog', 'category', 'view', 'id', '1523']
# ['brands', 'plax']
# ['brands', 'deep-depil']
# ['brands', 'provoc']
# ['brands', 'leonor-greyl']
# ['brands', 'christina-fitzgerald']
# ['brands', 'village-11-factory']
# ['brands', 'colab']
# ['brands', 'wet-brush']
# ['brands', 'victoria-shu']
# ['brands', 'comptoir-sud-pacifique']
# ['brands', 'swiss-smile']
# ['brands', 'white-glo']
# ['brands', 'nano-organic']
# ['catalog', 'category', 'view', 'id', '1544']
# ['brands', 'secret-day']
# ['brands', 'azka']
# ['brands', 'clarette']
# ['brands', 'mona-liza']
# ['brands', 'vilhelm-parfumerie']
# ['brands', 'nivea']
# ['brands', 'kose-cosmeport']
# ['brands', 'kocostar']
# ['brands', 'tampax']
# ['brands', '12-parfumeurs-francais']
# ['brands', 'foodaholic']
# ['brands', 'arau-baby']
# ['brands', 'nishane']
# ['brands', 'charles-worthington']
# ['brands', 'cleanic']
# ['catalog', 'category', 'view', 'id', '1574']
# ['brands', 'coola']
# ['brands', 'cremorlab']
# ['brands', 'royal-langnickel']
# ['catalog', 'category', 'view', 'id', '1593']
# ['brands', 'binturong']
# ['catalog', 'category', 'view', 'id', '1597']
# ['brands', 'elfarma']
# ['brands', 'sergey-naumov']
# ['brands', 'fresh-bubble']
# ['brands', 'la-soyul']
# ['brands', 'sun-smile']
# ['brands', 'el-skin']
# ['brands', 'moist-diane']
# ['brands', 'rokolor']
# ['brands', 'estel-professional']
# ['catalog', 'category', 'view', 'id', '1615']
# ['brands', 'frienvita']
# ['brands', 'biocon']
# ['brands', 'korloff-paris']
# ['brands', 'bliss-organic']
# ['brands', 'megrhythm']
# ['brands', 'beauugreen']
# ['brands', 'rich-hair']
# ['brands', 'chamos']
# ['brands', 'doctor-sea']
# ['brands', 'ora2']
# ['brands', 'lorigine']
# ['brands', 'white-organia']
# ['brands', 'bebble']
# ['catalog', 'category', 'view', 'id', '1633']
# ['catalog', 'category', 'view', 'id', '1635']
# ['brands', 'lasplash-cosmetics']
# ['brands', 'tan-master']
# ['brands', 'beautydrugs']
# ['brands', 'tony-guy']
# ['brands', 'montale']
# ['brands', 'moodmatcher']
# ['brands', 'rainbowbeauty']
# ['catalog', 'category', 'view', 'id', '1650']
# ['brands', 'shik']
# ['brands', 'dentalpro']
# ['brands', 'perioe']
# ['brands', 'lactacyd']
# ['brands', 'laquale']
# ['brands', 'chistaja-linija']
# ['brands', 'mijin-care']
# ['brands', 'eylure']
# ['brands', 'dongbang']
# ['brands', 'yashinomi']
# ['brands', 'ecotools']
# ['brands', 'cotex']
# ['brands', 'eat-my-bobbles']
# ['brands', 'mischa-vidyaev']
# ['brands', 'ja-samaja']
# ['brands', 'smartenamel']
# ['brands', 'krimle']
# ['brands', 'salon-deflouveil']
# ['brands', 'solnce-i-luna']
# ['brands', 'chanson-cosmetics']
# ['brands', 'la-kry']
# ['brands', 'model-rock-lashes']
# ['brands', 'shavo-green']
# ['brands', 'lucas-papaw-remedies']
# ['brands', 'make-up-factory']
# ['brands', 'isprey']
# ['brands', 'le-petit-marseillais']
# ['brands', 'l-arte-del-bello']
# ['brands', 'barnangen']
# ['brands', 'malen-kaja-feja']
# ['brands', 'eco-shugaring']
# ['catalog', 'category', 'view', 'id', '1715']
# ['brands', 'jurrasic-spa']
# ['brands', 'montcarotte']
# ['brands', 'naturalium']
# ['catalog', 'category', 'view', 'id', '1727']
# ['brands', 'l-oreal-professionnel']
# ['brands', 'adria-elegant-green']
# ['brands', 'aerin']
# ['brands', 'aha']
# ['brands', 'alvin-dor']
# ['brands', 'arau']
# ['brands', 'beauty-shop']
# ['brands', 'bigaku']
# ['brands', 'beyu']
# ['brands', 'bubchen']
# ['brands', 'cefine']
# ['brands', 'concept']
# ['brands', 'discreet']
# ['brands', 'dr-barbara-sturm']
# ['brands', 'dry-dry']
# ['brands', 'ekel']
# ['brands', 'ghd']
# ['brands', 'huggies']
# ['brands', 'kerasys']
# ['brands', 'krygina-cosmetics']
# ['brands', 'kualita']
# ['brands', 'la-prairie']
# ['brands', 'lavera']
# ['brands', 'lazurico']
# ['brands', 'lebelage']
# ['brands', 'little-devil']
# ['brands', 'lululun']
# ['brands', 'nioxin']
# ['brands', 'opi']
# ['brands', 'organic-people']
# ['brands', 'pampers']
# ['brands', 'pantenol']
# ['brands', 'parle-moi-de-parfum']
# ['brands', 'reach']
# ['brands', 'rouge-bunny-rouge']
# ['brands', 'start-epil']
# ['brands', 'topicrem']
# ['brands', 'tsururi']
# ['brands', 'flacon-magazine']
# ['brands', 'ureshino']
# ['brands', 'white-secret']
# ['brands', 'princess']
# ['brands', 'erborian']
# ['azija', 'makijazh', 'dlja-lica', 'prajmery']
# ['azija', 'makijazh', 'dlja-lica', 'tonal-nye-sredstva']
# ['azija', 'makijazh', 'dlja-lica', 'korrektory-i-konsilery']
# ['azija', 'makijazh', 'dlja-lica', 'bronzery-i-konturing']
# ['azija', 'makijazh', 'dlja-lica', 'pudra']
# ['azija', 'makijazh', 'dlja-lica', 'rumjana']
# ['azija', 'makijazh', 'dlja-lica', 'hajlajtery']
# ['azija', 'makijazh', 'dlja-glaz', 'baza-dlja-makijazha']
# ['azija', 'makijazh', 'dlja-glaz', 'podvodka']
# ['azija', 'makijazh', 'dlja-glaz', 'glitter']
# ['azija', 'makijazh', 'dlja-glaz', 'karandash-dlja-glaz']
# ['azija', 'makijazh', 'dlja-glaz', 'teni-dlja-vek']
# ['azija', 'makijazh', 'dlja-glaz', 'tush-dlja-resnic']
# ['azija', 'makijazh', 'dlja-gub', 'gubnaja-pomada']
# ['azija', 'makijazh', 'dlja-gub', 'blesk-dlja-gub']
# ['azija', 'makijazh', 'dlja-gub', 'karandash-dlja-gub']
# ['azija', 'makijazh', 'dlja-gub', 'uhod-dlja-gub']
# ['azija', 'makijazh', 'brovi', 'gel-ja-dlja-brovej']
# ['azija', 'makijazh', 'brovi', 'karandash-dlja-brovej']
# ['azija', 'makijazh', 'brovi', 'teni-dlja-brovej']
# ['azija', 'volosy', 'special-nyj-uhod', 'maski']
# ['azija', 'volosy', 'special-nyj-uhod', 'skraby']
# ['azija', 'volosy', 'special-nyj-uhod', 'maslo']
# ['azija', 'uhod', 'uhod-dlja-lica', 'ochischenie-i-demakijazh']
# ['azija', 'uhod', 'uhod-dlja-lica', 'osnovnoj-uhod']
# ['azija', 'uhod', 'uhod-dlja-lica', 'special-nyj-uod']
# ['azija', 'uhod', 'uhod-dlja-lica', 'syvorotki']
# ['azija', 'uhod', 'uhod-dlja-lica', 'antivozrastnoj-uhod']
# ['azija', 'uhod', 'uhod-dlja-lica', 'uhod-dlja-gub']
# ['azija', 'uhod', 'uhod-dlja-tela', 'dlja-tela']
# ['azija', 'uhod', 'uhod-dlja-tela', 'dlja-nog']
# ['azija', 'uhod', 'uhod-dlja-tela', 'dlja-ruk']
# ['azija', 'uhod', 'uhod-dlja-tela', 'dezodoranty']
# ['azija', 'uhod', 'uhod-dlja-tela', 'anticelljulitnye-i-korrektirujuschie-sredstva']
# ['azija', 'uhod', 'uhod-dlja-tela', 'uhod-dlja-polosti-rta']
# ['azija', 'uhod', 'uhod-dlja-tela', 'dlja-dusha-i-vanny']
# ['azija', 'uhod', 'uhod-dlja-tela', 'lichnaja-gigiena']
# ['organika', 'uhod', 'uhod-dlja-lica', 'osnovnoj-uhod']
# ['organika', 'uhod', 'uhod-dlja-lica', 'ochischenie-i-demakijazh']
# ['organika', 'uhod', 'uhod-dlja-lica', 'syvorotki']
# ['organika', 'uhod', 'uhod-dlja-lica', 'maski']
# ['organika', 'uhod', 'uhod-dlja-lica', 'antivozrastnoj-uhod']
# ['organika', 'uhod', 'uhod-dlja-lica', 'special-nyj-uhod']
# ['organika', 'uhod', 'uhod-dlja-lica', 'muzhskoj-uhod']
# ['organika', 'uhod', 'uhod-dlja-tela', 'dlja-dusha-i-vanny']
# ['organika', 'uhod', 'uhod-dlja-tela', 'dlja-tela']
# ['organika', 'uhod', 'uhod-dlja-tela', 'uhod-dlja-polosti-rta']
# ['organika', 'uhod', 'uhod-dlja-tela', 'dlja-ruk']
# ['organika', 'uhod', 'uhod-dlja-tela', 'dlja-nog']
# ['brands', '3ina']
# ['brands', 'dr-jart']
# ['brands', 'kenzo', 'parfjumerija-nabory']
# ['brands', 'clarins', 'antivozrastnoj-uhod']
# ['brands', 'clarins', 'solnechnaja-linija']
# ['brands', 'clarins', 'muzhskoj-uhod']
# ['brands', '3ina', 'lico']
# ['brands', '3ina', 'guby']
# ['brands', '3ina', 'paletki']
# ['brands', '3ina', 'glaza']
# ['brands', '3ina', 'brovi']
# ['brands', '3ina', 'kisti']
# ['brands', 'l-arvore']
# ['brands', 'elmolu']
# ['novinki']
# ['novinki', 'makijazh']
# ['novinki', 'uhod']
# ['brands', 'bobbi-brown', 'guby']
# ['brands', 'bobbi-brown', 'glaza']
# ['brands', 'bobbi-brown', 'scheki']
# ['brands', 'bobbi-brown', 'makijazh', 'prajmery']
# ['brands', 'bobbi-brown', 'makijazh', 'tonal-nye-sredstva']
# ['brands', 'bobbi-brown', 'scheki', 'bronzirujuschie-pudry']
# ['brands', 'bobbi-brown', 'makijazh', 'korrektory-i-konsilery']
# ['brands', 'bobbi-brown', 'scheki', 'pudry-hajlajtery']
# ['brands', 'bobbi-brown', 'makijazh', 'paletki-i-nabory']
# ['brands', 'bobbi-brown', 'uhod-za-kozhej', 'ochischenie-tonizirovanie']
# ['brands', 'bobbi-brown', 'uhod-za-kozhej', 'uvlazhnenie']
# ['brands', 'bobbi-brown', 'uhod-za-kozhej', 'maski']
# ['brands', 'bobbi-brown', 'uhod-za-kozhej', 'linija-jekstra']
# ['brands', 'bobbi-brown', 'uhod-za-kozhej', 'syvorotki-jeliksiry']
# ['brands', 'bobbi-brown', 'prinadlezhnosti-i-aksessuary']
# ['brands', 'bobbi-brown', 'uhod-za-kozhej', 'special-nyj-uhod']
# ['novinki', 'volosy']
# ['novinki', 'parfjumerija']
# ['novinki', 'azija']
# ['brands', 'biolage']
# ['brands', 'clinique', 'aromaty', 'zhenskie-aromaty']
# ['brands', 'clinique', 'aromaty', 'muzhskie-aromaty']
# ['brands', 'clinique', 'makijazh', 'lico', 'bazy-pod-makijazh']
# ['brands', 'clinique', 'makijazh', 'lico', 'ton']
# ['brands', 'clinique', 'makijazh', 'lico', 'pudry']
# ['brands', 'clinique', 'makijazh', 'lico', 'rumjana']
# ['brands', 'clinique', 'makijazh', 'lico', 'korrektirujuschie-sredstva']
# ['brands', 'clinique', 'makijazh', 'glaza', 'teni']
# ['brands', 'clinique', 'makijazh', 'glaza', 'konturnye-karandashi-i-podvodki']
# ['brands', 'clinique', 'makijazh', 'glaza', 'tush']
# ['brands', 'clinique', 'makijazh', 'glaza', 'brovi']
# ['brands', 'clinique', 'makijazh', 'guby']
# ['brands', 'clinique', 'uhod', 'clinique-id', 'shag-1-uvlazhnjajuschaja-baza']
# ['brands', 'clinique', 'uhod', 'clinique-id', 'shag-2-aktivnyj-koncentrat']
# ['brands', 'clinique', 'uhod', 'uhod-za-licom', 'ochischenie-i-snjatie-makijazha']
# ['brands', 'clinique', 'uhod', 'uhod-za-licom', 'uvlazhnenie']
# ['brands', 'clinique', 'uhod', 'uhod-za-licom', 'kremy-syvorotki-dlja-lica']
# ['brands', 'clinique', 'uhod', 'uhod-za-licom', 'uhod-za-kozhej-vokrug-glaz-i-gubami']
# ['brands', 'clinique', 'uhod', 'uhod-za-licom', 'maski-dlja-lica']
# ['brands', 'clinique', 'uhod', 'uhod-za-telom']
# ['brands', 'clinique', 'uhod', 'zaschita-ot-solnca']
# ['brands', 'clinique', 'dlja-muzhchin', 'ochischenie']
# ['brands', 'clinique', 'dlja-muzhchin', 'brit-e']
# ['brands', 'clinique', 'dlja-muzhchin', 'uvlazhenine']
# ['brands', 'clinique', 'dlja-muzhchin', 'telo']
# ['brands', 'clinique', 'nabory']
# ['brands', 'clinique', 'aksessuary']
# ['brands', 'tom-ford', 'makijazh']
# ['brands', 'tom-ford', 'nogti']
# ['brands', 'tom-ford', 'uhod', 'dlja-muzhchin']
# ['brands', 'estee-lauder', 'uhod-za-kozhej', 'ochischajuschie-tonizirujuschie-sredstva']
# ['brands', 'estee-lauder', 'uhod-za-kozhej', 'vosstanavlivajuschie-syvorotki']
# ['brands', 'estee-lauder', 'uhod-za-kozhej', 'uvlazhnjajuschie-kremy']
# ['brands', 'estee-lauder', 'uhod-za-kozhej', 'maski-otshelushivajuschie-sredstva']
# ['catalog', 'category', 'view', 'id', '2055']
# ['brands', 'estee-lauder', 'makijazh', 'lico', 'baza-pod-makijazh']
# ['brands', 'estee-lauder', 'makijazh', 'lico', 'tonal-naja-osnova']
# ['brands', 'estee-lauder', 'makijazh', 'lico', 'pudra']
# ['brands', 'estee-lauder', 'makijazh', 'lico', 'konsillery']
# ['brands', 'estee-lauder', 'makijazh', 'glaza', 'sredstvo-dlja-korrekcii-brovej']
# ['brands', 'estee-lauder', 'makijazh', 'glaza', 'tush']
# ['brands', 'estee-lauder', 'makijazh', 'guby', 'pomada']
# ['brands', 'estee-lauder', 'makijazh', 'guby', 'bal-zam-dlja-gub']
# ['brands', 'estee-lauder', 'aromaty', 'zhenskie-aromaty']
# ['brands', 'estee-lauder', 'uhod-za-kozhej', 'uhod-za-kozhej-vokrug-glaz']
# ['brands', 'promakeup-laboratory']
# ['brands', 'mac', 'makijazh']
# ['brands', 'mac', 'makijazh', 'glaza', 'sredstva-dlja-brovej']
# ['brands', 'mac', 'makijazh', 'lico', 'rumjana']
# ['brands', 'mac', 'makijazh', 'lico', 'pudra']
# ['brands', 'mac', 'makijazh', 'lico', 'ton']
# ['brands', 'mac', 'makijazh', 'lico', 'korrektory-hajlajtery']
# ['brands', 'mac', 'makijazh', 'glaza', 'teni']
# ['brands', 'mac', 'makijazh', 'glaza', 'karandashi-dlja-glaz-podvodki']
# ['brands', 'mac', 'makijazh', 'glaza', 'tush']
# ['brands', 'mac', 'makijazh', 'guby']
# ['brands', 'mac', 'uhod-za-kozhej', 'uvlazhnjajuschie-sredstva']
# ['brands', 'mac', 'uhod-za-kozhej', 'ochischenie']
# ['brands', 'mac', 'uhod-za-kozhej', 'prep-prime-fix']
# ['brands', 'mac', 'kisti-prinadlezhnosti']
# ['brands', 'kilian', 'aromaty', 'soblaznjajuschie']
# ['brands', 'kilian', 'aromaty', 'my-kind-of-love', 'princess']
# ['brands', 'kilian', 'aromaty', 'my-kind-of-love', 'adults']
# ['brands', 'by-kilian', 'dlja-tela']
# ['brands', 'by-kilian', 'refily']
# ['brands', 'darphin', 'uhod-za-kozhej', 'uvlazhnenie']
# ['brands', 'darphin', 'uhod-za-kozhej', 'uhod-za-chuvstvitel-noj-kozhej']
# ['brands', 'darphin', 'uhod-za-kozhej', 'pitanie']
# ['brands', 'darphin', 'uhod-za-kozhej', 'bor-ba-s-pigmentaciej']
# ['brands', 'darphin', 'uhod-za-kozhej', 'antivozrastnoj-uhod']
# ['brands', 'darphin', 'uhod-za-kozhej', 'sijanie']
# ['brands', 'suntique']
# ['brands', 'giorgio-armani', 'novinki']
# ['brands', 'lumene']
# ['brands', 'sebastian-professional']
# ['catalog', 'category', 'view', 'id', '2173']
# ['brands', 'blendsmart']
# ['brands', 'ecooking']
# ['brands', 'yadah']
# ['brands', 'cosworker']
# ['brands', 'tntn-mom-s']
# ['brands', 'cafe-mimi']
# ['brands', 'laurier']
# ['brands', 'clinique', '3-stupenchataja-sistema', 'shag-1-ochischenie']
# ['brands', 'clinique', '3-stupenchataja-sistema', 'shag-2-otshelushivanie']
# ['brands', 'clinique', '3-stupenchataja-sistema', 'shag-3-uvlazhenine']
# ['brands', 'silkoplast']
# ['brands', 'castelbajac']
# ['catalog', 'category', 'view', 'id', '2873']
# ['catalog', 'category', 'view', 'id', '2874']
# ['catalog', 'category', 'view', 'id', '2875']
# ['catalog', 'category', 'view', 'id', '2876']
# ['catalog', 'category', 'view', 'id', '2877']
# ['catalog', 'category', 'view', 'id', '2878']
# ['brands', 'lolita-lempicka']
# ['brands', 'dr-smart']
# ['brands', 'la-mer', 'uhod', 'uvlazhnenie']
# ['brands', 'la-mer', 'uhod', 'glaza']
# ['brands', 'la-mer', 'uhod', 'syvorotki']
# ['brands', 'la-mer', 'uhod', 'maski']
# ['brands', 'la-mer', 'uhod', 'osobyj-uhod']
# ['brands', 'la-mer', 'uhod', 'ochischenie-i-toniki']
# ['brands', 'la-mer', 'uhod', 'telo']
# ['brands', 'la-mer', 'uhod', 'genaissance']
# ['brands', 'la-mer', 'mini-formaty']
# ['brands', 'la-mer', 'nabory']
# ['brands', 'mac', 'bestsellery', 'guby']
# ['brands', 'mac', 'bestsellery', 'glaza']
# ['brands', 'mac', 'bestsellery', 'lico']
# ['brands', 'mac', 'bestsellery', 'uhod']
# ['brands', 'mac', 'makijazh', 'guby', 'pomady']
# ['brands', 'mac', 'makijazh', 'guby', 'bleski']
# ['brands', 'mac', 'makijazh', 'guby', 'uhod-i-prajmer']
# ['brands', 'mac', 'nabory']
# ['brands', 'mac', 'aromaty', 'shadescents']
# ['brands', 'mac', 'aromaty', 'turquatic']
# ['brands', 'mac', 'kollekcii', 'prep-prime-uhod-i-podgotovka-k-makijazhu']
# ['brands', 'mac', 'kollekcii', 'pro-longwear-stojkij-makijazh']
# ['brands', 'mac', 'kollekcii', 'mineralize-uhod-makijazh']
# ['brands', 'mac', 'kollekcii', 'lightful-c-rovnyj-ton-i-sijanie-kozhi']
# ['brands', 'mac', 'kollekcii', 'studio-ideal-noe-pokrytie']
# ['brands', 'mac', 'new']
# ['brands', 'kenzo', 'bestsellery']
# ['brands', 'tweezerman']
# ['brands', 'koelcia']
# ['makijazh', 'lico', 'matirujuschie-salfetki']
# ['brands', 'cle-de-peau-beaute']
# ['brands', 'bobbi-brown', 'scheki', 'rumjana']
# ['brands', 'revolution-pro']
# ['brands', 'note']
# ['brands', 'orly']
# ['brands', 'jo-malone-london']
# ['brands', 'its-skin']
# ['brands', 'fructis']
# ['brands', 'johnsons']
# ['brands', 'sinsation-cosmetics']
# ['brands', 'hello-beauty']
# ['brands', 'aussie']
# ['catalog', 'category', 'view', 'id', '3022']
# ['brands', 'barbasol']
# ['brands', 'carmex']
# ['brands', 'godefroy']
# ['catalog', 'category', 'view', 'id', '3033']
# ['brands', 'ardell']
# ['brands', 'cactus']
# ['brands', 'cosmetea']
# ['brands', 'lv-berner']
# ['brands', 'cosrx']
# ['brands', 'dr-lola']
# ['brands', 'hosa']
# ['brands', 'pillingbean']
# ['brands', 'qyoqyo']
# ['brands', 'dessange']
# ['brands', 'nature-republic']
# ['brands', 'galenic']
# ['brands', 'tnt']
# ['brands', 'royal-and-langnickel']
# ['brands', 'larvore']
# ['brands', 'saborino']
# ['brands', 'filorga']
# ['brands', 'lip-smacker']
# ['brands', 'chopard']
# ['brands', 'cosmogony']
# ['brands', 'dyson']
# ['brands', 'organic-kitchen']
# ['brands', 'juno']
# ['catalog', 'category', 'view', 'id', '3073']
# ['brands', 'elastine']
# ['brands', 'treaclemoon']
# ['brands', 'amazingcosmetics']
# ['brands', 'dolce-gabbana']
# ['brands', 'ok-beauty']
# ['brands', 'true-island']
# ['brands', 'ground-plan']
# ['makijazh', 'novinki']
# ['uhod', 'novinki']
# ['volosy', 'novinki']
# ['parfjumerija', 'novinki']
# ['azija', 'novinki']
# ['rasprodazha', 'makijazh']
# ['rasprodazha', 'azija']
# ['rasprodazha', 'uhod']
# ['rasprodazha', 'volosy']
# ['rasprodazha', 'parfjumerija']
# ['rasprodazha', 'parfjumerija', 'zhenskie-aromaty']
# ['rasprodazha', 'parfjumerija', 'muzhskie-aromaty']
# ['rasprodazha', 'parfjumerija', 'nishevaja-parfjumerija']
# ['rasprodazha', 'parfjumerija', 'zhenskie-aromaty', 'tualetnaja-voda']
# ['rasprodazha', 'parfjumerija', 'zhenskie-aromaty', 'parfjumernaja-voda']
# ['rasprodazha', 'parfjumerija', 'zhenskie-aromaty', 'odekolon']
# ['rasprodazha', 'parfjumerija', 'muzhskie-aromaty', 'tualetnaja-voda']
# ['rasprodazha', 'parfjumerija', 'muzhskie-aromaty', 'parfjumernaja-voda']
# ['rasprodazha', 'parfjumerija', 'nishevaja-parfjumerija', 'tualetnaja-voda']
# ['rasprodazha', 'parfjumerija', 'nishevaja-parfjumerija', 'parfjumernaja-voda']
# ['brands', 'milani-cosmetics']
# ['rasprodazha', 'makijazh', 'lico']
# ['rasprodazha', 'makijazh', 'lico', 'prajmery']
# ['rasprodazha', 'makijazh', 'lico', 'tonal-nye-sredstva']
# ['rasprodazha', 'makijazh', 'lico', 'korrektory-i-konsilery']
# ['rasprodazha', 'makijazh', 'lico', 'bronzery-i-konturing']
# ['rasprodazha', 'makijazh', 'lico', 'fiksatory-dlja-makijazha']
# ['rasprodazha', 'makijazh', 'lico', 'pudra']
# ['rasprodazha', 'makijazh', 'lico', 'rumjana']
# ['rasprodazha', 'makijazh', 'lico', 'hajlajtery']
# ['rasprodazha', 'makijazh', 'glaza']
# ['rasprodazha', 'makijazh', 'glaza', 'baza-dlja-makijazha']
# ['rasprodazha', 'makijazh', 'glaza', 'podvodka']
# ['rasprodazha', 'makijazh', 'glaza', 'karandash-dlja-glaz']
# ['rasprodazha', 'makijazh', 'glaza', 'teni-dlja-vek']
# ['rasprodazha', 'makijazh', 'glaza', 'tush-dlja-resnic']
# ['rasprodazha', 'makijazh', 'guby']
# ['rasprodazha', 'makijazh', 'guby', 'gubnaja-pomada']
# ['rasprodazha', 'makijazh', 'guby', 'blesk-dlja-gub']
# ['rasprodazha', 'makijazh', 'guby', 'karandash-dlja-gub']
# ['rasprodazha', 'makijazh', 'guby', 'uhod-dlja-gub']
# ['rasprodazha', 'makijazh', 'brovi']
# ['rasprodazha', 'makijazh', 'brovi', 'gel-dlja-brovej']
# ['rasprodazha', 'makijazh', 'brovi', 'karandash-dlja-brovej']
# ['rasprodazha', 'makijazh', 'brovi', 'teni-dlja-brovej']
# ['rasprodazha', 'makijazh', 'brovi', 'tush-dlja-brovej']
# ['rasprodazha', 'makijazh', 'nogti']
# ['rasprodazha', 'makijazh', 'nogti', 'lak-dlja-nogtej']
# ['rasprodazha', 'makijazh', 'nogti', 'baza-i-top']
# ['rasprodazha', 'makijazh', 'nogti', 'sredstva-dlja-snjatija-laka']
# ['rasprodazha', 'makijazh', 'nogti', 'dlja-manikjura']
# ['rasprodazha', 'makijazh', 'kisti']
# ['rasprodazha', 'makijazh', 'kisti', 'sredstva-dlja-ochistki-kistej']
# ['rasprodazha', 'makijazh', 'paletki']
# ['rasprodazha', 'makijazh', 'paletki', 'dlja-lica']
# ['rasprodazha', 'makijazh', 'paletki', 'dlja-glaz']
# ['rasprodazha', 'makijazh', 'paletki', 'dlja-gub']
# ['rasprodazha', 'makijazh', 'aksessuary']
# ['rasprodazha', 'uhod', 'uhod-dlja-lica']
# ['rasprodazha', 'uhod', 'uhod-dlja-lica', 'ochischenie-i-demakijazh']
# ['rasprodazha', 'uhod', 'uhod-dlja-lica', 'osnovnoj-uhod']
# ['rasprodazha', 'uhod', 'uhod-dlja-lica', 'special-nyj-uhod']
# ['rasprodazha', 'uhod', 'uhod-dlja-lica', 'antivozrastnoj-uhod']
# ['rasprodazha', 'uhod', 'uhod-dlja-lica', 'muzhskoj-uhod']
# ['rasprodazha', 'uhod', 'uhod-dlja-lica', 'syvorotki']
# ['rasprodazha', 'uhod', 'uhod-dlja-lica', 'maski']
# ['rasprodazha', 'uhod', 'uhod-dlja-lica', 'uhod-dlja-gub']
# ['rasprodazha', 'uhod', 'uhod-dlja-lica', 'patchi']
# ['rasprodazha', 'uhod', 'uhod-dlja-tela']
# ['rasprodazha', 'uhod', 'uhod-dlja-tela', 'dlja-tela']
# ['rasprodazha', 'uhod', 'uhod-dlja-tela', 'dlja-dusha-i-vanny']
# ['rasprodazha', 'uhod', 'uhod-dlja-tela', 'dezodoranty']
# ['rasprodazha', 'uhod', 'uhod-dlja-tela', 'anticelljulitnye-i-korrektirujuschie-sredstva']
# ['rasprodazha', 'uhod', 'uhod-dlja-tela', 'detskij-uhod']
# ['rasprodazha', 'uhod', 'uhod-dlja-tela', 'uhod-za-polost-ju-rta']
# ['rasprodazha', 'uhod', 'uhod-dlja-tela', 'dlja-ruk']
# ['rasprodazha', 'uhod', 'uhod-dlja-tela', 'dlja-nog']
# ['rasprodazha', 'uhod', 'solnechnaja-linija']
# ['rasprodazha', 'volosy', 'shampun']
# ['rasprodazha', 'volosy', 'kondicioner']
# ['rasprodazha', 'volosy', 'suhoj-shampun']
# ['rasprodazha', 'volosy', 'dlja-stilistov']
# ['rasprodazha', 'volosy', 'dlja-stilistov', 'shampun']
# ['rasprodazha', 'volosy', 'dlja-stilistov', 'maski']
# ['rasprodazha', 'volosy', 'dlja-stilistov', 'maslo']
# ['rasprodazha', 'volosy', 'dlja-stilistov', 'uhod-dlja-volos']
# ['brands', 'kevyn-aucoin']
# ['brands', 'cle-de-peau-beaute', 'uhod']
# ['brands', 'cle-de-peau-beaute', 'uhod', 'ochischenie']
# ['brands', 'cle-de-peau-beaute', 'uhod', 'bazovyj-uhod']
# ['brands', 'cle-de-peau-beaute', 'uhod', 'supreme']
# ['brands', 'cle-de-peau-beaute', 'uhod', 'special-nyj-uhod']
# ['brands', 'cle-de-peau-beaute', 'uhod', 'zaschita-ot-solnca']
# ['brands', 'cle-de-peau-beaute', 'uhod', 'uhod-za-telom']
# ['brands', 'cle-de-peau-beaute', 'synactif']
# ['brands', 'cle-de-peau-beaute', 'makijazh']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'lico']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'guby']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'glaza']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'kisti-i-aksessuary']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'lico', 'baza-pod-makijazh']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'lico', 'korrektory']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'lico', 'tonal-nye-sredstva']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'lico', 'pudry']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'lico', 'cvetnoj-makijazh']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'guby', 'pomady']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'guby', 'bal-zamy']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'guby', 'bleski']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'guby', 'karandashi']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'glaza', 'tush-dlja-resnic']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'glaza', 'teni-dlja-vek']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'glaza', 'podvodka-karandashi']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'glaza', 'brovi']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'kisti-i-aksessuary', 'kisti']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'kisti-i-aksessuary', 'sponzhi-puhovki']
# ['brands', 'cle-de-peau-beaute', 'makijazh', 'kisti-i-aksessuary', 'futljary']
# ['brands', 'freedom']
# ['brands', 'cle-de-peau-beaute', 'uhod', 'radiance-trio']
# ['brands', 'l-oreal-professionnel', 'tip-volos']
# ['brands', 'l-oreal-professionnel', 'bestsellery']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'okrashennye']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'svetlye-osvetlennye']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'povrezhdennye']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'suhie-i-oslablennye-volosy']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'vypadenie-volos']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'v-juschiesja-neposlushnye']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'plotnye']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'tonkie']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'lomkie']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'sedye']
# ['brands', 'l-oreal-professionnel', 'tip-volos', 'dlja-kozhi-golovy']
# ['brands', 'l-oreal-professionnel', 'tip-produkta', 'shampun']
# ['brands', 'l-oreal-professionnel', 'tip-produkta', 'kondicioner']
# ['brands', 'l-oreal-professionnel', 'tip-produkta', 'maska']
# ['brands', 'l-oreal-professionnel', 'tip-produkta', 'krem']
# ['brands', 'l-oreal-professionnel', 'tip-produkta', 'syvorotka']
# ['brands', 'l-oreal-professionnel', 'tip-produkta', 'sprej-uhod']
# ['brands', 'l-oreal-professionnel', 'tip-produkta', 'sprej-kamufljazh']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'vosstanovlenie-povrezhdennyh-volos']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'sohranenie-cveta-okrashennyh-volos']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'predotvraschenie-vypadenija-i-istonchenija-volos']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'super-ob-em']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'krasivyj-ottenok-blond']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'disciplina-volos']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'vosstanovlenie-balansa-kozhi-golovy']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'termozaschita']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'sokratit-lomkost-pri-raschesyvanii']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'fiksacija']
# ['brands', 'l-oreal-professionnel', 'potrebnost', 'tekstura']
# ['brands', 'l-oreal-professionnel', 'gammy', 'liss-unlimited']
# ['brands', 'l-oreal-professionnel', 'gammy', 'serioxyl']
# ['brands', 'l-oreal-professionnel', 'gammy', 'blondifier']
# ['brands', 'l-oreal-professionnel', 'gammy', 'vitamino-color']
# ['brands', 'l-oreal-professionnel', 'gammy', 'aminexil']
# ['brands', 'l-oreal-professionnel', 'gammy', 'steampod']
# ['brands', 'l-oreal-professionnel', 'gammy', 'tecni-art']
# ['brands', 'l-oreal-professionnel', 'gammy', 'volumetry']
# ['brands', 'l-oreal-professionnel', 'gammy', 'absolut-repair-lipidium']
# ['brands', 'l-oreal-professionnel', 'gammy', 'inforcer']
# ['brands', 'l-oreal-professionnel', 'gammy', 'pure-resourse']
# ['brands', 'l-oreal-professionnel', 'gammy', 'silver']
# ['brands', 'l-oreal-professionnel', 'gammy', 'smartbond']
# ['brands', 'l-oreal-professionnel', 'gammy', 'infinium']
# ['brands', 'amazingcosmetics', 'lico']
# ['brands', 'amazingcosmetics', 'kisti']
# ['brands', 'amazingcosmetics', 'bestsellery']
# ['brands', 'momo-puri']
# ['brands', 'dg', 'zhenskie-aromaty']
# ['brands', 'dolce-gabbana', 'zhenskie-aromaty', 'dolce']
# ['brands', 'dg', 'zhenskie-aromaty', 'the-one']
# ['brands', 'dolce-gabbana', 'zhenskie-aromaty', 'the-only-one']
# ['brands', 'dg', 'zhenskie-aromaty', 'pour-femme']
# ['brands', 'dg', 'zhenskie-aromaty', 'intense']
# ['brands', 'dolce-gabbana', 'zhenskie-aromaty', 'light-blue']
# ['brands', 'dg', 'muzhskie-aromaty']
# ['brands', 'dg', 'muzhskie-aromaty', 'intenso']
# ['brands', 'dg', 'muzhskie-aromaty', 'the-one-for-men']
# ['brands', 'dg', 'muzhskie-aromaty', 'pour-homme']
# ['brands', 'dg', 'muzhskie-aromaty', 'light-blue-pour-homme']
# ['brands', 'omorovicza', 'uhod-za-licom']
# ['brands', 'omorovicza', 'kollekcii']
# ['brands', 'omorovicza', 'kollekcii', 'hydro-mineral-collection']
# ['brands', 'omorovicza', 'kollekcii', 'moor-mud-collection']
# ['brands', 'omorovicza', 'kollekcii', 'gold-collection']
# ['brands', 'omorovicza', 'kollekcii', 'blue-diamond-collection']
# ['brands', 'lancome', 'bestsellery']
# ['brands', 'lancome', 'absolue']
# ['brands', 'lancome', 'kollekcija-aromatov-maison']
# ['brands', '3w-clinic']
# ['brands', 'closeup']
# ['brands', 'vilenta']
# ['brands', 'l-a-girl']
# ['brands', 'scinic']
# ['brands', 'sante']
# ['brands', 'enough']
# ['brands', 'etude-house']
# ['brands', 'depiltouch-professional']
# ['brands', 'giorgio-armani', 'bestsellery']
# ['brands', 'giorgio-armani', 'makijazh', 'lico']
# ['brands', 'white-smile']
# ['brands', 'irc']
# ['brands', 'chi']
# ['brands', 'paglieri-1876']
# ['catalog', 'category', 'view', 'id', '3485']
# ['brands', 'goldapplebox']
# ['brands', 'laurent-mazzone']
# ['brands', 'modamo']
# ['brands', 'huangjisoo']
# ['brands', '22-11']
# ['brands', 'clive-christian']
# ['brands', 'botany-essentials']
# ['brands', 'sensido']
# ['brands', 'bio-world']
# ['brands', 'kilian', 'aromaty', 'my-kind-of-love', 'after-sunset']
# ['brands', 'annemarie-borlind']
# ['brands', 'onme']
# ['brands', 'silva']
# ['brands', 'johnny-s-chop-shop']
# ['brands', 'pravilnaya-kosmetika']
# ['brands', 'meizer']
# ['brands', 'dentrala']
# ['brands', 'r-co']
# ['brands', 'cholley']
# ['brands', 'mom']
# ['brands', 'yves-saint-laurent', 'bestsellery']
# ['catalog', 'category', 'view', 'id', '3548']
# ['brands', 'logona']
# ['brands', 'foreo']
# ['catalog', 'category', 'view', 'id', '3558']
# ['brands', 'omorovicza', 'uhod-za-telom']
# ['brands', 'nautica']
# ['brands', 'vera-wang']
# ['brands', 'dr-brandt']
# ['brands', 'eveline']
# ['brands', 'nyx-professional-makeup', 'aksessuary']
# ['brands', 'nyx-professional-makeup', 'novinki']
# ['brands', 'nyx-professional-makeup', 'bestsellery']
# ['brands', 'clarins', 'nabory']
# ['catalog', 'category', 'view', 'id', '3609']
# ['brands', 'evo']
# ['brands', 'lebel']
# ['brands', 'shingmulnara']
# ['brands', 'chanel']
# ['brands', 'vera']
# ['podarochnye-nabory', 'uhod']
# ['podarochnye-nabory', 'makijazh']
# ['podarochnye-nabory', 'parfjumerija']
# ['podarochnye-nabory', 'volosy']
# ['podarochnye-nabory', 'muzhskie-nabory']
# ['podarochnye-nabory', 'zhenskie-nabory']
# ['podarochnye-nabory']
# ['brands', 'jo-malone-london', 'bestsellery']
# ['brands', 'jo-malone-london', 'aromaty-i-kollekcii']
# ['brands', 'jo-malone-london', 'aromaty-i-kollekcii', 'odekolony']
# ['brands', 'on-the-body']
# ['brands', 'tech']
# ['brands', 'dior']
# ['brands', 'dior', 'zhenskie-aromaty']
# ['brands', 'dior', 'muzhskie-aromaty']
# ...
# ['f', 'cafe-mimi-maska-dlya-volos']
# ['f', 'zhidkost-dlya-snyatiya-laka-dnc']
# ['f', 'mom-skrab']
# ['f', 'green-mama-dlya-umyvaniya']
# ['f', 'tush-dlya-resnits-trevel-format']
# ['f', 'rexona-dezodoranty-zhenskij']
# ['f', 'rozovaja-paletka-tenej']
# ['f', 'solntsezashchitnyy-krem-dlya-litsa']
# ['f', 'professionalnyye-maski-dlya-sukhikh-volos']
# ['f', 'gel-dlya-borody']
# ['f', 'maslo-dlya-litsa-dnc']
# ['f', 'alterna-shampun-dlya-volos']
# ['f', 'molochko-dlya-snyatiya-makiyazha-green-mama']
# ['f', 'tonalnyy-krem-trevel-format']
# ['f', 'weleda-dezodoranty']
# ['f', 'gel-dlja-brovej-brown']
# ['f', 'solntsezashchitnyy-krem-dlya-tela']
# ['f', 'maski-dlya-okrashennykh-volos-professionalnyye']
# ['f', 'carolina-herrera-dukhi-muzhskiye']
# ['f', 'dnc-maska-dlya-litsa']
# ['f', 'konditsioner-alterna']
# ['f', 'penka-dlya-umyvaniya-green-mama']
# ['f', 'ukhodnyy-praymer-trevel-format']
# ['f', 'loreal-paris-kraska-dlja-volos']
# ['f', 'palmolive-gel-dlja-dusha']
# ['f', 'gel-dlja-brovej-artdeco']
# ['f', 'lacoste-zhenskiy-parfum']
# ['f', 'maslo-dlya-sukhikh-volos']
# ['f', 'biore-penka-dlya-umyvaniya']
# ['f', 'dnc-syvorotka-dlya-litsa']
# ['f', 'sukhoy-shampun-alterna']
# ['f', 'sredstva-dlya-snyatiya-makiyazha-sante']
# ['f', 'fiksiruyushchiy-sprey-trevel-format']
# ['f', 'krem-vichy']
# ['f', 'barhatnye-ruchki-krem-dlja-ruk']
# ['f', 'tush-rimmel']
# ['f', 'caudalie-krem']
# ['f', 'l-oreal-elseve-shampun']
# ['f', 'maski-dlya-oslablennykh-volos']
# ['f', 'clinique-uvlazhnyayushchiy-krem-dlya-litsa']
# ['f', 'ukhod-za-nogami-dnc']
# ['f', 'syvorotka-alterna']
# ['f', 'penka-dlya-umyvaniya-hada-labo']
# ['f', 'gel-dlya-dusha-mini-format']
# ['f', 'krem-nivea']
# ['f', 'nivea-krem-dlja-ruk']
# ['f', 'tush-yves-saint-laurent']
# ['f', 'biotherm-krem']
# ['f', 'organika-maslo']
# ['f', 'tonik-dlya-volos']
# ['f', 'clinique-uvlazhnyayushchiy-gel']
# ['f', 'maska-dlya-ruk-dnc']
# ['f', 'maslo-alterna']
# ['f', 'green-mama-krem-dlya-nog']
# ['f', 'zubnaya-pasta-mini-format']
# ['f', 'maybelline-gubnaja-pomada']
# ['f', 'dove-krem']
# ['f', 'blue-mascara']
# ['f', 'krem-dlja-nog-uvlazhnenie']
# ['f', 'detskoye-zhidkoye-mylo']
# ['f', 'ampuly-dlya-volos']
# ['f', 'clinique-krem-dlya-litsa']
# ['f', 'dnc-ukhod-za-volosami']
# ['f', 'maska-alterna']
# ['f', 'maska-nosochki-dlya-nog-vilenta']
# ['f', 'kremy-mini-format']
# ['f', 'chistaya-liniya-krem']
# ['f', 'garnier-maski']
# ['f', 'tush-catrice']
# ['f', 'krem-dlja-ruk-antivozrastnoj']
# ['f', 'zubnaya-shchetka-splat']
# ['f', 'zhenskiye-tsitrusovyye-aromaty']
# ['f', 'estee-lauder-parfum']
# ['f', 'maslo-dlya-volos-dnc']
# ['f', 'sprey-alterna']
# ['f', 'krem-dlya-ruk-green-mama']
# ['f', 'losony-mini-format']
# ['f', 'parfjumernaja-voda-tom-ford']
# ['f', 'lactacyd-lichnaja-gigiena']
# ['f', 'tush-guerlain']
# ['f', 'krem-dlja-ruk-natura-siberica']
# ['f', 'uvlazhnyayushchiy-sprey-dlya-tela']
# ['f', 'zhenskiye-tsvetochnyye-aromaty']
# ['f', 'maska-dlya-volos-dnc']
# ['f', 'annayake-krem']
# ['f', 'sante-krem-dlya-ruk']
# ['f', 'maski-dlya-litsa-mini-format']
# ['f', 'krem-clarins']
# ['f', 'biorepair-zybnaya-pasta']
# ['f', 'tush-armani']
# ['f', 'cafe-mimi-krem-dlja-ruk']
# ['f', 'versace-tualetnaya-voda-zhenskaya']
# ['f', 'zhenskiye-pudrovyye-aromaty']
# ['f', 'lancome-parfum-zhenskiy']
# ['f', 'zhenskaya-britva-dorco']
# ['f', 'annayake-loson']
# ['f', 'green-mama-gel-dlya-intimnoy-gigiyeny']
# ['f', 'maslo-dlya-litsa-mini-format']
# ['f', 'colgate-zybnaya-pasta']
# ['f', 'tush-nyx']
# ['f', 'clarins-krem-dlja-ruk']
# ['f', 'vivienne-sabo-tush-dlya-brovey']
# ['f', 'zhenskiye-muskusnyye-aromaty']
# ['f', 'koreyskoye-mylo-dlya-litsa']
# ['f', 'muzhskiye-shampuni-dove']
# ['f', 'syvorotka-annayake']
# ['f', 'schwarzkopf-professional-stayling']
# ['f', 'mitsellyarnaya-voda-mini-format']
# ['f', 'natura-siberica-shampun']
# ['f', 'curaprox-zubnaya-shchetka']
# ['f', 'fioletovaja-tush']
# ['f', 'krem-dlja-ruk-dove']
# ['f', 'zhenskaya-nishevaya-parfyumeriya']
# ['f', 'zhidkiye-patchi-levrana']
# ['f', 'dove-gel-dlya-dusha-muzhskoy']
# ['f', 'zubnaya-shchetka-lacalut']
# ['f', 'patchi-trevel-format']
# ['f', 'hugo-boss-parfjum']
# ['f', 'paradontax-zybnaya-pasta']
# ['f', 'tush-shiseido']
# ['f', 'krem-dlja-ruk-eveline']
# ['f', 'zhenskaya-nishevyye-dukhi']
# ['f', 'dove-dezodorant-muzhskoy']
# ['f', 'penka-dlya-umyvaniya-mini-format']
# ['f', 'christian-dior-tualetnaja-voda']
# ['f', 'president-zybnaya-pasta']
# ['f', 'tush-tom-ford']
# ['f', 'krem-dlja-ruk-loccitane']
# ['f', 'muzhskaya-nishevaya-parfyumeriya']
# ['f', 'dove-konditsioner-dlya-volos']
# ['f', 'syvorotka-blithe']
# ['f', 'koreyskaya-matovaya-pomada']
# ['f', 'syvorotki-dlya-litsa-mini-format']
# ['f', 'vilenta-maski']
# ['f', 'rocs-zubnaya-shchetka']
# ['f', 'tush-artdeco']
# ['f', 'loccitane-shampun']
# ['f', 'alginatnyye-maski-korea']
# ['f', 'gel-dlya-dusha-dove']
# ['f', 'blithe-maska']
# ['f', 'koreyskiye-paletki-dlya-litsa']
# ['f', 'tonik-dlya-litsa-mini-format']
# ['f', 'hugo-boss-muzhskie']
# ['f', 'tush-helena-rubinstein']
# ['f', 'shampun-onme']
# ['f', 'piling-babor']
# ['f', 'mitsellyarnaya-voda-dove']
# ['f', 'blithe-essentsiya']
# ['f', 'koreyskiy-balzam-dlya-gub']
# ['f', 'essentsiya-dlya-litsa-mini-format']
# ['f', 'britva-gillette']
# ['f', 'splat-zybnaya-pasta']
# ['f', 'tush-isadora']
# ['f', 'cafe-mimi-shampun']
# ['f', 'tkanevyye-maski-garnier']
# ['f', 'podarochnyye-nabory-dove']
# ['f', 'patchi-blom']
# ['f', 'balzamy-dlya-volos-mini-format']
# ['f', 'novinki-zhenskih-duhov']
# ['f', 'matrix-maslo']
# ['f', 'tush-sensai']
# ['f', 'shampun-oribe']
# ['f', 'bronziruyushchiye-pudry']
# ['f', 'muss-dlya-umyvaniya-dove']
# ['f', 'mikroigolnyye-patchi-blom']
# ['f', 'vosk-dlya-volos-mini-format']
# ['f', 'shampun-vichy']
# ['f', 'aussie-shampun']
# ['f', 'tush-estrade']
# ['f', 'mylo-dove']
# ['f', 'krem-dlya-volos-mini-format']
# ['f', 'loreal-tush-dlja-resnic']
# ['f', 'biolage-shampun']
# ['f', 'tush-lumene']
# ['f', 'vosk-dlja-volos-zhenskij']
# ['f', 'kitayskiye-tkanevyye-maski-dlya-litsa']
# ['f', 'zhidkoye-mylo-dove']
# ['f', 'lak-dlya-volos-mini-format']
# ['f', 'chi-shampun']
# ['f', 'tush-dlja-brovej-essence']
# ['f', 'tualetnaja-voda-unisex']
# ['f', 'yaponskiye-tkanevyye-maski-dlya-litsa']
# ['f', 'krem-dlya-volos-elseve']
# ['f', 'koreyskiy-balzam-dlya-litsa']
# ['f', 'loson-dlya-volos-mini-format']
# ['f', 'concept-shampun']
# ['f', 'konsiler-nyx']
# ['f', 'vivienne-sabo-pudra']
# ['f', 'yaponskiy-poroshok']
# ['f', 'maska-dlya-volos-elseve']
# ['f', 'gel-dlya-dusha-camay']
# ['f', 'koreyskiye-ochishchayushchiye-balzamy-dlya-litsa']
# ['f', 'maski-dlya-volos-mini-format']
# ['f', 'davines-shampun']
# ['f', 'tonal-nij-krem-nyx']
# ['f', 'pudra-estrade']
# ['f', 'etude-house-mitsellyarnaya-voda']
# ['f', 'camay-dezodorant']
# ['f', 'koreyskiye-ochishchayushchiye-geli-dlya-litsa']
# ['f', 'maslo-dlya-volos-mini-format']
# ['f', 'calvin-klein-tualetnaja-voda']
# ['f', 'hajlajtery-nyx']
# ['f', 'pudra-divage']
# ['f', 'levrana-gel-dlya-umyvaniya']
# ['f', 'etude-house-tonalnaya-osnova']
# ['f', 'mylo-camay']
# ['f', 'kremy-comfort-zone']
# ['f', 'koreyskiye-geli-dlya-uvlazhneniya-litsa']
# ['f', 'pasta-dlya-volos-mini-format']
# ['f', 'hugo-boss-tualetnaja-voda']
# ['f', 'indola-shampun']
# ['f', 'karandash-dlja-gub-nyx']
# ['f', 'la-prairie-pudra']
# ['f', 'gidrogelevyye-patchi-dlya-glaz']
# ['f', 'penka-dlya-umyvaniya-etude-house']
# ['f', 'intimnaya-gigiyena-carefree']
# ['f', 'maslo-comfort-zone']
# ['f', 'koreyskiye-antivozrastnyye-geli-dlya-litsa']
# ['f', 'penka-i-muss-dlya-volos-mini-format']
# ['f', 'loreal-gubnaja-pomada']
# ['f', 'kerasys-shampun']
# ['f', 'karandash-dlja-brovej-nyx']
# ['f', 'teni-dlja-brovej-vivienne-sabo']
# ['f', 'naturalnyy-shampun-dlya-zhirnykh-volos']
# ['f', 'gidrogelevyye-patchi-dlya-glaz-korea']
# ['f', 'carefree-yezhednevnyye-prokladki']
# ['f', 'comfort-zone-nabor']
# ['f', 'koreyskiye-ochishchayushchiye-geli-dlya-chuvstvitelnoy-kozhi']
# ['f', 'skrab-dlya-volos-mini-format']
# ['f', 'etude-organix-povyazki-dlya-volos']
# ['f', 'celranico-krem']
# ['f', 'korea']
# ['f', 'christina-uvlazhnyayushchiy-krem']
# ['f', 'elizavecca-syvorotki']
# ['f', 'krem-christina']
# ['f', 'gel-christina']
# ['f', 'christina-tonik-dlya-litsa']
# ['f', 'cillit-bang-dlya-kuhni']
# ['f', 'syvorotka-christina']
# ['f', 'cillit-bang-dlya-vannoy-i-tualeta']
# ['f', 'christina-piling']
# ['f', 'skrab-christina']
# ['f', 'maska-dlya-litsa-christina']
# ['f', 'christina-dlya-problemnoy-kozhi']
# ['f', 'krem-dlya-litsa-klapp-cosmetics']
# ['f', 'christina-dlya-zhirnoy-kozhi']
# ['f', 'syvorotka-klapp-cosmetics']
# ['f', 'maska-klapp-cosmetics']
# ['f', 'klapp-cosmetics-tonik']
# ['f', 'sredstva-dlja-stirki-meine-liebe']
# ['f', 'kenzo-parfum-zhenskiy']
# ['f', 'duhi-creed-zhenskie']
# ['f', 'krem-jigott']
# ['f', 'jigott-piling']
# ['f', 'jigott-penka-dlya-umyvaniya']
# ['f', 'dessange-shampun']
# ['f', 'maska-dlya-litsa-jigott']
# ['f', 'l-occitane-krem']
# ['f', 'kotex-tampony']
# ['f', 'tualetnaya-voda-guerlain-zhenskaya']
# ['f', 'yezhednevnyye-prokladki-kotex']
# ['f', 'kley-dlya-resnits-ardell']
# ['f', 'ardell-resnitsy']
# ['f', 'clarins-tonalnyy-flyuid']
# ['f', 'krem-avene-dlya-sukhoy-kozhi']
# ['f', 'avene-dlya-chuvstvitelnoy-kozhi']
# ['f', 'himalaya-herbals-krem-pitanie']
# ['f', 'himalaya-herbals-krem']
# ['f', 'ga-de-highlighter']
# ['f', 'pudra-ga-de']
# ['f', 'ga-de-tonalnyy-krem']
# ['f', 'clean-home-dlya-kukhni']
# ['f', 'pomada-ga-de']
# ['f', 'clean-home-dlya-vanny']
# ['f', 'krem-elemis']
# ['f', 'ga-de-karandash-dlya-gub']
# ['f', 'clean-home-sol-dlya-vann']
# ['f', 'podvodka-ga-de']
# ['f', 'teni-ga-de']
# ['f', 'rumyana-ga-de']
# ['f', 'mustela-nabor']
# ['f', 'ga-de-karandash-dlya-glaz']
# ['f', 'paletka-ga-de']
# ['f', 'blesk-ga-de']
# ['f', 'clarins-avtozagar']
# ['f', 'tush-ga-de']
# ['f', 'krem-dlya-litsa-lirene']
# ['f', 'krem-galenic']
# ['f', 'gel-dlya-umyvaniya-lirene']
# ['f', 'galenic-syvorotka']
# ['f', 'lirene-mitsellyarnaya-voda']
# ['f', 'galenic-molochko']
# ['f', 'lirene-piling']
# ['f', 'greenini-krem-dlya-volos']
# ['f', 'gel-dlya-umyvaniya-greenini']
# ['f', 'greenini-sprey']
# ['f', 'greenini-patchi']
# ['f', 'maska-greenini']
# ['f', 'parfjumerija-dior']
# ['f', 'attack-stiralnyy-poroshok']
# ['f', 'pyatnovyvoditel-attack']
# ['f', 'sukhoye-maslo-milv-dlya-nogtey']
# ['f', 'milv-skrab']
# ['f', 'shampun-moroccanoil']
# ['f', 'konditsioner-moroccanoil']
# ['f', 'moroccanoil-lak-dlya-volos']
# ['f', 'sukhiye-shampuni-moroccanoil']
# ['f', 'maslo-dlya-volos-moroccanoil']
# ['f', 'loson-dlya-volos-moroccanoil']
# ['f', 'penka-it-s-skin']
# ['f', 'maska-dlya-volos-moroccanoil']
# ['f', 'uvlazhnyayushchaya-syvorotka-it-s-skin']
# ['f', 'rascheska-moroccanoil']
# ['f', 'it-s-skin-krem-dlya-litsa']
# ['f', 'it-s-skin-syvorotka-dlya-litsa']
# ['f', 'krem-la-prairie']
# ['f', 'pudra-guerlain']
# ['f', 'krem-guerlain']
# ['f', 'guerlain-parfum']
# ['f', 'guerlain-teni']
# ['f', 'ninelle-pudra']
# ['f', 'ninelle-pomada']
# ['f', 'karandash-dlya-gub-ninelle']
# ['f', 'ninelle-karandash-dlya-brovey']
# ['f', 'podvodka-ninelle']
# ['f', 'teni-ninelle']
# ['f', 'rumyana-ninelle']
# ['f', 'tonalnyy-krem-ninelle']
# ['f', 'blesk-dlya-gub-ninelle']
# ['f', 'alginatnyye-maski-ninelle']
# ['f', 'tush-ninelle']
# ['f', 'ninelle-maski-dlya-litsa']
# ['f', 'vitaminnyy-kompleks-vitrum']
# ['f', 'acqua-di-parma-parfum']
# ['f', 'zubnaya-shchetka-jordan']
# ['f', 'acqua-di-parma-duhi']
# ['f', 'supradin-kids']
# ['f', 'luma-highlighter']
# ['f', 'zdravsiti-vitaminno-mineralnyy-kompleks']
# ['f', 'make-up-for-ever-pudra-prozrachnaya']
# ['f', 'make-up-for-ever-tonalnyy-krem']
# ['f', 'krem-opi']
# ['f', 'karandash-dlya-gub-make-up-for-ever']
# ['f', 'baza-opi']
# ['f', 'baza-pod-makiyazh-make-up-for-ever']
# ['f', 'paletka-dior-backstage']
# ['f', 'make-up-for-ever-karandash-dlya-glaz']
# ['f', 'make-up-for-ever-tush']
# ['f', 'prezervativy-luxe']
# ['f', 'zubnaya-pasta-jordan']
# ['f', 'make-up-for-ever-paletka']
# ['f', 'portupeya']
# ['f', 'make-up-for-ever-highlighter']
# ['f', 'krem-dlya-litsa-matis']
# ['f', 'matis-maska']
# ['f', 'pediakid-dlya-immuniteta']
# ['f', 'stimulyatory-satisfyer']
# ['f', 'vaginalnyye-shariki-satisfyer']
# ['f', 'vibratory-satisfyer']
# ['f', 'seks-igrushki-dlya-muzhchin']
# ['f', 'seks-igrushki-dlya-zhenshchin']
# ['f', 'stimulyatory-klitora']
# ['f', 'vibroyaytsa-i-vibropuli']
# ['f', 'mini-vibratory']
# ['f', 'vaginalnyye-shariki-i-trenazhery']
# ['f', 'diptyque-parfum']
# ['f', 'erektsionnyye-koltsa']
# ['f', 'seks-nabory-dlya-zhenshchin']
# ['f', 'stimulyatory-dlya-muzhchin']
# ['f', 'stimulyatory-dlya-zhenshchin']
# ['f', 'sergi-nothing-but-love']
# ['f', 'elizavecca-maski']
# ['f', 'filorga-krem']
# ['f', 'foreo-maska']
# ['f', 'funs-kondicioner']
# ['f', 'silver-ring']
# ['f', 'kol-ca-sokolov']
# ['f', 'krem-viteks']
# ['f', 'krem-perricone-md']
# ['f', 'braslet-sokolov']
# ['f', 'penka-dlya-umyvaniya-viteks']
# ['f', 'syvorotka-perricone-md']
# ['f', 'ser-gi-sokolov']
# ['f', 'viteks-maski-dlya-litsa']
# ['f', 'tide-gel-dlya-stirki']
# ['f', 'secret-nature-krem']
# ['f', 'podveska-sokolov']
# ['f', 'syvorotka-secret-nature']
# ['f', 'secret-nature-maska-dlya-litsa']
# ['f', 'krem-shary']
# ['f', 'syvorotka-shary']
# ['f', 'shary-matiruyushchiye-salfetki']
# ['f', 'maska-shary']
# ['f', 'maski-dlya-litsa-tkanevyye-shary']
# ['f', 'annbeauty-kisti']
# ['f', 'anskin-alginatnyye-maski']
# ['f', 'anskin-tkanevaya-maska']
# ['f', 'shampun-system-professional']
# ['f', 'skrab-plu']
# ['f', 'pomada-provoc']
# ['f', 'provoc-karandash-dlya-gub']
# ['f', 'provoc-karandash-dlya-brovey']
# ['f', 'podvodka-dlya-glaz-provoc']
# ['f', 'guerlain-parfum-zhenskiy']
# ['f', 'provoc-teni']
# ['f', 'detskiye-ukrasheniya']
# ['f', 'guerlain-tualetnaya-voda-muzhskaya']
# ['f', 'tochilka-provoc']
# ['f', 'zhenskiye-ukrasheniya']
# ['f', 'guerlain-tualetnaya-voda-zhenskaya']
# ['f', 'kisti-provoc']
# ['f', 'guerlain-duhi-zhenskie-novinka']
# ['f', 'shampun-rich-hair']
# ['f', 'guerlain-muzhskoy-parfum']
# ['f', 'konditsioner-egomania']
# ['f', 'initio-parfums-prives-parfum']
# ['f', 'rich-hair-maska-dlya-volos']
# ['f', 'amouage-duhi-zhenskie']
# ['f', 'amouage-man']
# ['f', 'lak-christina-fitzgerald']
# ['f', 'kenzo-parfum']
# ['f', 'sante-highlighter']
# ['f', 'sante-pudra']
# ['f', 'krem-22-11']
# ['f', 'piling-elizavecca']
# ['f', 'shampuni-sante']
# ['f', 'elizavecca-tkanevie-maski']
# ['f', 'pomada-sante']
# ['f', 'elizavecca-patchi']
# ['f', 'teni-sante']
# ['f', 'elizavecca-penka-dlja-umivanja']
# ['f', 'sante-gel-dlya-dusha']
# ['f', 'matiruyushchiye-salfetki-etude-organix']
# ['f', 'sante-konsiler']
# ['f', 'butylochki-dlya-kormleniya-mam']
# ['f', 'tush-dlya-resnits-sante']
# ['f', 'pustyshki-mam']
# ['f', 'dezodorant-sante']
# ['f', 'balzam-dlya-gub-sante']
# ['f', 'reuzel-shampun']
# ['f', 'rexaline-maska']
# ['f', 'rexaline-krem']
# ['f', 'kevin-murphy-spray']
# ['f', 'nochnoy-krem-clarins']
# ['f', 'skinlite-maski-dlya-litsa']
# ['f', 'make-up-for-ever-pomada']
# ['f', 'elizavecca-krem']
# ['f', 'skinlite-patchi']
# ['f', 'pudra-make-up-for-ever']
# ['f', 'sesderma-solntsezashchitnyy-krem']
# ['f', 'skinlite-syvorotka']
# ['f', 'teni-make-up-for-ever']
# ['f', 'sesderma-loson-dlya-snyatiya-makiyazha']
# ['f', 'krem-sesderma-ot-morshchin']
# ['f', 'krem-dlja-voloc-moroccanoil']
# ['f', 'krem-sesderma']
# ['f', 'sprej-dlja-volos-moroccanoil']
# ['f', 'losony-sesderma']
# ['f', 'nabor-moroccanoil']
# ['f', 'sesderma-syvorotka']
# ['f', 'sesderma-molochko-dlya-tela']
# ['f', 'flyuid-sesderma']
# ['f', 'sesderma-dlya-chuvstvitelnoy-kozhi']
# ['f', 'sesderma-dlya-problemnoy-kozhi']
# ['f', 'osvezhiteli-vozdukha']
# ['f', 'rybiy-zhir-vitateka']
# ['f', 'dry-dry-dezodoranty']
# ['f', 'kenzo-tualetnaya-voda-muzhskaya']
# ['f', 'vlazhnyye-salfetki-solnce-i-luna']
# ['f', 'serebryanyye-koltsa-dlya-detey']
# ['f', 'serebryanyye-sergi-dlya-detey']
# ['f', 'vibratory-iz-silikona']
# ['f', 'analnyye-vibratory']
# ['f', 'prezervativy-iz-lateksa']
# ['f', 'prezervativy-iz-poliuretana']
# ['f', 'kenzo-tualetnaya-voda-zhenskaya']
# ['f', 'nabory-vaginalnykh-sharikov']
# ['f', 'masturbatory']
# ['f', 'by-kilian-parfjumernaja-voda']
# ['f', 'vozbuzhdayushchiye-balzamy']
# ['f', 'bebble-krem-detskiy']
# ['f', 'maslo-dlya-intimnogo-massazha']
# ['f', 'zhidkiye-patchi-mixit']
# ['f', 'bebble-shampun-detskiy']
# ['f', 'krem-declare']
# ['f', 'svechi-dlya-massazha']
# ['f', 'declare-tonik']
# ['f', 'syvorotka-declare']
# ['f', 'dezodoranty-declare']
# ['f', 'maski-declare']
# ['f', 'filorga-ot-morshchin']
# ['f', 'krem-dlya-glaz-clarins']
# ['f', 'sredstvo-dlya-stirki-detskogo-belya-burti']
# ['f', 'kremy-ot-morshchin-filorga']
# ['f', 'burti-zhidkoye-sredstvo-dlya-stirki']
# ['f', 'loson-filorga']
# ['f', 'stiralnyy-poroshok']
# ['f', 'syvorotka-filorga']
# ['f', 'filorga-nabor']
# ['f', 'filorga-maska']
# ['f', 'maska-dlya-litsa-etude-organix']

# %%
class Product:
    def __init__(self, product_page, product_url:str=None, product_id:int=None, sku_id:int=None):
        self.product_page: etree._Element = etree.HTML(product_page)
        self.product_url = product_url
        self.product_id: int or None = product_id
        self.sku_id: int or None = sku_id
        self.title: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/header/p')[0].text.strip() \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/header/p')) > 0 \
            else None
        self.first_subcategory: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[2]/a/span')[0].text.strip() \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[2]/a/span')) > 0 \
            else None
        self.second_subcategory: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[3]/a/span')[0].text.strip() \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[3]/a/span')) > 0 \
            else None
        self.third_subcategory: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[4]/a/span')[0].text.strip() \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[4]/a/span')) > 0 \
            else None
        self.fourth_subcategory: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[5]/a/span')[0].text.strip() \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[5]/a/span')) > 0 \
            else None
        self.price: int or None = int(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/form/div[3]/div/div/span/span/span/span')[0].text.replace('₽', '').replace(u'\xa0', u' ').replace(u' ', u'').strip()) \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/form/div[3]/div/div/span/span/span/span')) > 0 \
            else None
        self.loyalty_price: int or None = int(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/form/div[3]/div/span/span/span/span')[0].text.replace('₽', '').replace(u'\xa0', u' ').replace(u' ', u'').strip()) \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[1]/section[3]/div/form/div[3]/div/span/span/span/span')) > 0 \
            else None
        self.description: str or None = ' '.join(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[1]')[0].text.replace('\n\n', '').split()) \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[1]')) > 0 \
            else None
        self.product_usage: str or None = ' '.join(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[2]/article/div/section')[0].text.replace('\n\n', '').split()) \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[2]/article/div/section')) > 0 \
            else None
        self.product_composition: str or None = ' '.join(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[3]/article/div/section')[0].text.replace('\n\n', '').split()) \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[3]/article/div/section')) > 0 \
            else None
        self.product_brand: str or None = self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[3]/article/div/header/h4/span')[0].text \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[3]/article/div/header/h4/span')) > 0 \
            else None or self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[2]/article/div/header/h4/span')[0].text \
            if len(self.product_page.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[2]/article/div/header/h4/span')) > 0 \
            else None

# %%
len(product_urls)
# Out:
# 72182

# %%
url = product_urls[4000]
res = requests.get(url, timeout=(3, 5)).content.decode('utf-8')

# %%
url
# Out:
# 'https://goldapple.ru/24461400018-nejlonovye-volokna-10-1682'

# %%
res = requests.get('https://goldapple.ru/web_scripts/discover/category/products/', params={'cat': 3, 'page': 1}).json()['products']
len(res)
res[0]
# Out:
# {'id': '173372',
#  'sku': '19000016941',
#  'name': 'К122',
#  'brand': 'Manly PRO',
#  'brand_type': 'standard',
#  'dimension17': 'Кисти для лица',
#  'dimension18': 'Женский',
#  'dimension19': None,
#  'dimension20': None,
#  'country': 'Россия',
#  'price': 1630,
#  'price_object': {'amount': '1630', 'currency': 'RUB'},
#  'old_price': 1630,
#  'old_price_object': {'amount': '1630', 'currency': 'RUB'},
#  'category_type': 'Большая плоская кисть для пудры ',
#  'url': 'https://goldapple.ru/19000016941-k122',
#  'image_url': 'https://goldapple.ru/media/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg',
#  'webp_image_url': 'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
#  'images': ['https://goldapple.ru/media/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg',
#   'https://goldapple.ru/media/catalog/product/6/9/6921166812419_2_chfmwll08kkefjw8.jpg',
#   'https://goldapple.ru/media/catalog/product/6/9/6921166812419_3_3apxe5hspdnd5it6.jpg'],
#  'webp_images': ['https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
#   'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_2_chfmwll08kkefjw8.jpg?quality=83',
#   'https://goldapple.ru/web_scripts/webp/catalog/product/6/9/6921166812419_3_3apxe5hspdnd5it6.jpg?quality=83'],
#  'is_saleable': True,
#  'type': 'simple',
#  'volume': '1',
#  'tone_swatch': '',
#  'labels': [],
#  'resized_image_url': '',
#  'resized_images': [{'media': '(max-width: 375px)',
#    'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
#    'type': 'image/webp'},
#   {'media': '(max-width: 375px)',
#    'url': 'https://goldapple.ru/media/catalog/product/cache/24775fdfc4c7f873253df6fbbf296a97/6/9/6921166812419_1_mixjzksioyjod7da.jpg'},
#   {'media': '(min-width: 376px) and (max-width: 768px)',
#    'url': 'https://goldapple.ru/web_scripts/webp/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/6/9/6921166812419_1_mixjzksioyjod7da.jpg?quality=83',
#    'type': 'image/webp'},
#   {'media': '(min-width: 376px) and (max-width: 768px)',
#    'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/6/9/6921166812419_1_mixjzksioyjod7da.jpg'},
#   {'media': '(min-width: 769px) and (max-width: 1360px)',
#    'url': 'https://goldapple.ru/media/catalog/product/cache/d19ff61fc2489b2762000db60825d3b7/6/9/6921166812419_1_mixjzksioyjod7da.jpg'},
#   {'media': '(min-width: 1361px)',
#    'url': 'https://goldapple.ru/media/catalog/product/cache/7c72a742678f135337f3d39eb3099e35/6/9/6921166812419_1_mixjzksioyjod7da.jpg'}],
#  'resized_gallery_image_urls': [],
#  'resized_gallery_images': [],
#  'need_render_old_price': True,
#  'main_product_sku': '19000016941',
#  'main_product_id': '173372',
#  'ga_list_name': '',
#  'adultgood': False,
#  'best_loyalty_price': 1467,
#  'best_loyalty_price_object': {'amount': '1467', 'currency': 'RUB'},
#  'dimension29': False,
#  'dimension28': False,
#  'discover_tracking_click_url': 'http://recs.richrelevance.com/rrserver/apiclick?a=80fdecab677dbf85&cak=a850db30e0e760ca&channelId=a850db30e0e760ca&vg=5ce82721-7fd6-4bc6-d4cd-c86070325a6e&stid=165&mrrid=110081820&pti=4&pa=47968&pn=-1&pos=0&p=19000016941&rid=msk&mvtId=55814&mvtTs=1656797244373'}

# %%
res = requests.get('https://goldapple.ru/web_scripts/discover/category/products/', params={'cat': 3, 'page': 743}).json()['products']
len(res)
# Out:
# 15

# %%
from selenium import webdriver

browser = webdriver.Edge(executable_path='msedgedriver.exe')
browser.get(url)
html = browser.page_source
tree = etree.HTML(html)
tree.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[2]/a/span')
# Out:
# C:\Users\HardWorkingStation\AppData\Local\Temp\ipykernel_21452\2432559867.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Edge(executable_path='msedgedriver.exe')
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Input In [81], in <cell line: 3>()
#       1 from selenium import webdriver
# ----> 3 browser = webdriver.Edge(executable_path='msedgedriver.exe')
#       4 browser.get(url)
#       5 html = browser.page_source
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\edge\webdriver.py:61, in WebDriver.__init__(self, executable_path, port, options, service_args, capabilities, service_log_path, service, keep_alive, verbose)
#      58 if not service:
#      59     service = Service(executable_path, port, service_args, service_log_path)
# ---> 61 super().__init__(DesiredCapabilities.EDGE['browserName'], "ms",
#      62                  port, options,
#      63                  service_args, capabilities,
#      64                  service_log_path, service, keep_alive)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\chromium\webdriver.py:92, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      89 self.service.start()
#      91 try:
# ---> 92     super().__init__(
#      93         command_executor=ChromiumRemoteConnection(
#      94             remote_server_addr=self.service.service_url,
#      95             browser_name=browser_name, vendor_prefix=vendor_prefix,
#      96             keep_alive=keep_alive, ignore_proxy=_ignore_proxy),
#      97         options=options)
#      98 except Exception:
#      99     self.quit()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:277, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     275 self._authenticator_id = None
#     276 self.start_client()
# --> 277 self.start_session(capabilities, browser_profile)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:370, in WebDriver.start_session(self, capabilities, browser_profile)
#     368 w3c_caps = _make_w3c_caps(capabilities)
#     369 parameters = {"capabilities": w3c_caps}
# --> 370 response = self.execute(Command.NEW_SESSION, parameters)
#     371 if 'sessionId' not in response:
#     372     response = response['value']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: This version of Microsoft Edge WebDriver only supports Microsoft Edge version 105
# Current browser version is 103.0.1264.44 with binary path C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe
# Stacktrace:
# Backtrace:
# 	Microsoft::Applications::Events::EventProperties::unpack [0x00007FF68415B4A2+27426]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00007FF6840AF0C2+339266]
# 	Ordinal0 [0x00007FF683C47801+620545]
# 	Ordinal0 [0x00007FF683C73AC7+801479]
# 	Ordinal0 [0x00007FF683C6F6EC+784108]
# 	Ordinal0 [0x00007FF683C6A888+764040]
# 	Ordinal0 [0x00007FF683CA4ABF+1002175]
# 	Ordinal0 [0x00007FF683C9F1D3+979411]
# 	Ordinal0 [0x00007FF683C76020+811040]
# 	Ordinal0 [0x00007FF683C77618+816664]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF683F08A78+127864]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF683EF24BB+36283]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF683EF53FC+48380]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF683D50E23+22563]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00007FF6840B699B+370203]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00007FF6840BBED4+392020]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00007FF6840BC02D+392365]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF6840C6C89+41193]
# 	BaseThreadInitThunk [0x00007FFAC6E554E0+16]
# 	RtlUserThreadStart [0x00007FFAC898485B+43]

# %%
res

# %%
res_soup = bs4.BeautifulSoup(res, 'html.parser')
tree = etree.HTML(res)

# %%
res_soup.find('div', {'class': 'product-card'})
# Out:
# <div class="product-card"><div class="product-card__i"><div class="product-card__images _skeletoned"></div><div class="product-card__details"><div class="product-card__type"><span class="_skeletoned"></span><span class="_skeletoned"></span></div><div class="product-card__full-name"><span class="_skeletoned"></span><span class="_skeletoned"></span></div><div class="product-card__pricing"><span class="_skeletoned"></span></div></div></div></div>

# %%
tree.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[2]/a/span')
# Out:
# []

# %%
prod = Product(res)

# %%
prod.__dict__
# Out:
# {'product_page': <Element html at 0x1c85ba275c0>,
#  'product_url': None,
#  'product_id': None,
#  'sku_id': None,
#  'title': 'Кисть для тональной основы',
#  'first_subcategory': None,
#  'second_subcategory': None,
#  'third_subcategory': None,
#  'fourth_subcategory': None,
#  'price': 390,
#  'loyalty_price': 0,
#  'description': None,
#  'product_usage': None,
#  'product_composition': None,
#  'product_brand': None}

# %%
for x in res_soup.find_all('li', {'class': "pdp-breadcrumbs__crumb-item pdp-breadcrumbs__item"}):
    print(x.get_text())

# %%
str(etree.tostring(tree.xpath('/html/body')[0])).find('')
# Out:
# -1

# %%
product_properties = {}
for x in tree.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[2]/dl')[0]:
    print(x[0][0].text)
    if 'Тип продукта' in x[0][0].text:
        product_properties['product_type'] = x[1][0].text
    if 'Для кого' in x[0][0].text:
        product_properties['who_use'] = x[1][0].text
    if 'Страна бренда' in x[0][0].text:
        product_properties['brand_country'] = x[1][0].text
    if 'Область применения' in x[0][0].text:
        product_properties['use_scope'] = x[1][0].text
    if 'Назначение' in x[0][0].text:
        product_properties['purpose'] = x[1][0].text

product_properties

# %%
MyClass = type("MyClass", (object, ), product_properties)

# %%
link = 'https://goldapple.ru/14503-4551247598-rastusevka-bez-granicdsf'
pattern = re.compile(r'\d{4,20}')
res_sku = re.findall(pattern, link)
if len(res_sku) == 1:
    prod_id = None
    sku_id = res_sku[0]
elif len(res_sku) > 1:
    prod_id = res_sku[0]
    sku_id = res_sku[1]
else:
    prod_id = sku_id = None
print(res_sku)
print(prod_id, sku_id)

# %%
res
# Out:
# ' <!doctype html><html lang="ru" prefix="og: https://ogp.me/ns#"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# product: http://ogp.me/ns/product#"> <script>\n    var BASE_URL = \'https://goldapple.ru/\';\n    var require = {\n        "baseUrl": "https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU"\n    };</script> <meta charset="utf-8"/>\n<meta name="description" content="Купить Интенсивный тонирующий шампунь-уход Платинум Блонд EVO Platinum Blonde Toning Shampoo в Москве по низкой цене в интернет-магазине «Золотое яблоко». Подробное описание, применение, состав, фото. Бесплатная доставка по Москве и всей России от 1000 рублей."/>\n<meta name="keywords" content="Интенсивный тонирующий шампунь-уход Платинум Блонд, EVO, Platinum Blonde Toning Shampoo, интернет-магазин, Москва, Екатеринбург, Санкт-Петербург, Новосибирск, Казань, Самара, Ростов-на-Дону, Челябинск, Хабаровск, Саратов, Нижний Новгород, Волгоград, Пермь"/>\n<meta name="robots" content="INDEX,FOLLOW"/>\n<meta name="title" content="Интенсивный тонирующий шампунь-уход Платинум Блонд EVO Platinum Blonde Toning Shampoo — купить в Москве"/>\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0"/>\n<meta name="format-detection" content="telephone=no"/>\n<meta name="cmsmagazine" content="1996cc57595bba67a5c2c32d0f536af5"/>\n<meta name="yandex-verification" content="ffc6fac5f2c5e226"/>\n<meta name="google-site-verification" content="ezrvimRR4GAlPr4hpAjClEKAoRa4g2blIHJi9hPgMi8"/>\n<meta property="og:title" content="В наличии: Интенсивный тонирующий шампунь-уход Платинум Блонд EVO Platinum Blonde Toning Shampoo "/>\n<meta property="og:description" content="Интенсивный тонирующий шампунь-уход Платинум Блонд EVO Platinum Blonde Toning Shampoo — купить  в интернет-магазине «Золотое яблоко». Бесплатная доставка по Москве и всей России от 1000 рублей."/>\n<title>Интенсивный тонирующий шампунь-уход Платинум Блонд EVO Platinum Blonde Toning Shampoo — купить в Москве</title>\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/vendor/slick.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/header.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/navigation.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/main.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/city-selector.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/authorization.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/footer.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/vendor/auto-complete.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/modalsearch.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/bf-banner.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple/ru_RU/css/minicart.min.css" />\n<link  rel="stylesheet" type="text/css"  media="all" href="https://goldapple.ru/static/version1656623330/frontend/Mygento/goldapple ...

# %%
res_soup = bs4.BeautifulSoup(res_text, 'html.parser')
tree = etree.HTML(res)

# %%
prod = Product(res, )

# %%
prod.__dict__
# Out:
# {'product_page': <Element html at 0x15759f2acc0>,
#  'product_id': None,
#  'sku_id': None,
#  'title': 'Ёршики межзубные M d 3.0 мм',
#  'first_subcategory': None,
#  'second_subcategory': None,
#  'third_subcategory': None,
#  'fourth_subcategory': None,
#  'price': 504,
#  'loyalty_price': 453,
#  'description': 'Межзубные щетки (ершики) необходимы каждому человеку для тщательной очистки межзубных пространств. Также ими можно пользоваться для лучшей гигиены при ношении ортодонтических конструкций. Цилиндрические ершики Lacalut имеют высокопрочные нейлоновые щетинки и удобную цветную ручку. В упаковке комплект из 5 штук. Для подбора нужного диаметра ершиков необходимо обратиться за консультацией к стоматологу.',
#  'product_usage': 'Перед первым применением рекомендуется промыть межзубной ершик в теплой воде. После чистки каждой зоны и в конце чистки необходимо тщательно промыть межзубной ершик теплой водой. При ежедневном использовании рекомендуется менять межзубной ершик каждую неделю. Средство индивидуальной гигиены.',
#  'product_composition': 'LACALUT® -это бренд немецкой компании Dr. Theiss Naturwaren GmbH.',
#  'product_brand': 'LACALUT'}

# %%
for x in res_soup.find_all('li', {'class': "pdp-breadcrumbs__crumb-item pdp-breadcrumbs__item"}):
    print(x.get_text())

# %%
tree.xpath('/html/body/div[1]/main/div/div/section/header/section[1]/nav/ul/li[2]/a/span')
# Out:
# []

# %%
product_properties = {}
for x in tree.xpath('/html/body/div[1]/main/div/div/section/section[3]/section[2]/section/section[1]/div/ul/li[1]/article/div/section[2]/dl')[0]:
    print(x[0][0].text)
    if 'Тип продукта' in x[0][0].text:
        product_properties['product_type'] = x[1][0].text
    if 'Для кого' in x[0][0].text:
        product_properties['who_use'] = x[1][0].text
    if 'Страна бренда' in x[0][0].text:
        product_properties['brand_country'] = x[1][0].text
    if 'Область применения' in x[0][0].text:
        product_properties['use_scope'] = x[1][0].text
    if 'Назначение' in x[0][0].text:
        product_properties['purpose'] = x[1][0].text

product_properties
# Out:
# Тип продукта
# Для кого
# Назначение
# Область применения
# Страна бренда
# {'product_type': 'межзубный ершик',
#  'who_use': 'унисекс',
#  'purpose': 'личная гигиена',
#  'use_scope': 'для полости рта',
#  'brand_country': 'Германия'}

# %%
MyClass = type("MyClass", (object, ), product_properties)
# Out:
#   Input In [242]
#     MyClass.Для кого
#                 ^
# SyntaxError: invalid syntax

# %%
link = 'https://goldapple.ru/14503-4551247598-rastusevka-bez-granicdsf'
pattern = re.compile(r'\d{4,20}')
res_sku = re.findall(pattern, link)
if len(res_sku) == 1:
    prod_id = None
    sku_id = res_sku[0]
elif len(res_sku) > 1:
    prod_id = res_sku[0]
    sku_id = res_sku[1]
else:
    prod_id = sku_id = None
print(res_sku)
print(prod_id, sku_id)
# Out:
# ['14503', '4551247598']
# 14503 4551247598

# %%
product_urls[30000]
# Out:
# 'https://goldapple.ru/19760343449-platinum-blonde-toning-shampoo'
